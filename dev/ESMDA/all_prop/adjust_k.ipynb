# %%
import numpy as np
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
import geone
import geone.covModel as gcm
import geone.imgplot3d as imgplt3
import pyvista as pv
import sys
import os

sys.path.append("../../../")
#my modules
from ArchPy.base import *
from ArchPy.tpgs import *

# %%
#grid
sx = 1.5
sy = 1.5
sz = .15
x0 = 0
y0 = 0
z0 = -15
nx = 140
ny = 70
nz = 70
x1 = x0 + nx*sx
y1 = y0 + ny*sy
z1 = z0 + nz

dimensions = (nx, ny, nz)
spacing = (sx, sy, sz)
origin = (x0, y0, z0)  

domain = np.ones([ny,nx],dtype=bool)

# %%
## create pile

P1 = Pile(name = "P1",seed=1)
PD = Pile(name = "PD",seed=1)

#units covmodel
covmodelD = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[30,30]})])
covmodelD1 = gcm.CovModel2D(elem=[('cubic', {'w':0.2, 'r':[30,30]})])
covmodelC = gcm.CovModel2D(elem=[('cubic', {'w':0.2, 'r':[40,40]})])
covmodelB = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[30,30]})])
covmodel_er = gcm.CovModel2D(elem=[('spherical', {'w':1, 'r':[50,50]})])

## facies covmodel
covmodel_SIS_C = gcm.CovModel3D(elem=[("exponential", {"w":.21,"r":[50, 50, 10]})], alpha=0, name="vario_SIS") # input variogram
covmodel_SIS_B1 = gcm.CovModel3D(elem=[("exponential", {"w":.16,"r":[50, 50, 2]})], alpha=0, name="vario_SIS") # input variogram
covmodel_SIS_B2 = gcm.CovModel3D(elem=[("exponential", {"w":.24,"r":[100, 100, 3]})], alpha=0, name="vario_SIS") # input variogram
covmodel_SIS_B3 = gcm.CovModel3D(elem=[("exponential", {"w":.19,"r":[50, 50, 2]})], alpha=0, name="vario_SIS") # input variogram
covmodel_SIS_B4 = gcm.CovModel3D(elem=[("exponential", {"w":.13,"r":[100, 100, 4]})], alpha=0, name="vario_SIS") # input variogram

lst_covmodelC=[covmodel_SIS_C] # list of covmodels to pass at the function
lst_covmodelB=[covmodel_SIS_B1, covmodel_SIS_B2, covmodel_SIS_B3, covmodel_SIS_B4] # list of covmodels to pass


#create Lithologies 
dic_s_D2 = {"int_method" : "grf_ineq","covmodel" : covmodelD1}
dic_f_D2 = {"f_method":"homogenous"}
D2 = Unit(name="D2",order=1,ID = 10,color="goldenrod",contact="onlap",surface=Surface(contact="onlap",dic_surf=dic_s_D2),
          dic_facies=dic_f_D2)
dic_s_D1 = {"int_method" : "grf_ineq","covmodel" : covmodelD1, "mean":-6.5}
dic_f_D1 = {"f_method":"homogenous"}
D1 = Unit(name="D1",order=2,ID = 11,color="palegoldenrod",contact="onlap",surface=Surface(contact="onlap",dic_surf=dic_s_D1)
            ,dic_facies=dic_f_D1)


PD.add_unit([D1,D2])

dic_s_D = {"int_method" : "grf_ineq","covmodel" : covmodelD}
dic_f_D = {"f_method":"SubPile", "SubPile":PD}
D = Unit(name="D",order=1,ID = 1,color="gold",contact="onlap",surface=Surface(contact="onlap",dic_surf=dic_s_D)
         ,dic_facies=dic_f_D)

dic_s_C = {"int_method" : "grf_ineq","covmodel" : covmodelC, "mean":-7}
dic_f_C = {"f_method" : "SIS","neig" : 10, "f_covmodel":lst_covmodelC, "probability":[0.3, 0.7]}
C = Unit(name="C", order=2, ID = 2, color="blue", contact="onlap", dic_facies=dic_f_C, surface=Surface(dic_surf=dic_s_C, contact="onlap"))

dic_s_B = {"int_method" : "grf_ineq","covmodel" : covmodelB, "mean":-8.5}
dic_f_B = {"f_method":"SIS", "neig" : 10, "f_covmodel":lst_covmodelB, "probability":[0.2, 0.4, 0.25, 0.15]}
B = Unit(name="B",order=3,ID = 3,color="purple",contact="onlap",dic_facies=dic_f_B,surface=Surface(contact="onlap",dic_surf=dic_s_B))

dic_s_A = {"int_method":"grf_ineq","covmodel": covmodelB, "mean":-11}
dic_f_A = {"f_method":"homogenous"}
A = Unit(name="A",order=5,ID = 5,color="red",contact="onlap",dic_facies=dic_f_A,surface=Surface(dic_surf = dic_s_A,contact="onlap"))

#Master pile
P1.add_unit([D,C,B,A])
# Out:
# Unit D2: Surface added for interpolation
# Unit D1: Surface added for interpolation
# Stratigraphic unit D1 added
# Stratigraphic unit D2 added
# Unit D: Surface added for interpolation
# Unit C: Surface added for interpolation
# Unit B: Surface added for interpolation
# Unit A: Surface added for interpolation
# Stratigraphic unit D added
# Stratigraphic unit C added
# Stratigraphic unit B added
# Stratigraphic unit A added

# %%
# covmodels for the property model
covmodelK = gcm.CovModel3D(elem=[("exponential",{"w":0.3,"r":[30,30,10]})],alpha=-20,name="K_vario")
covmodelK2 = gcm.CovModel3D(elem=[("spherical",{"w":0.1,"r":[20,20, 5]})],alpha=0,name="K_vario_2")

facies_1 = Facies(ID = 1,name="Sand",color="yellow")
facies_2 = Facies(ID = 2,name="Gravel",color="lightgreen")
facies_3 = Facies(ID = 3,name="GM",color="blueviolet")
facies_4 = Facies(ID = 4,name="Clay",color="blue")
facies_5 = Facies(ID = 5,name="SM",color="brown")
facies_6 = Facies(ID = 6,name="Silt",color="goldenrod")
facies_7 = Facies(ID = 7,name="basement",color="red")

A.add_facies([facies_7])
B.add_facies([facies_1, facies_2, facies_3, facies_5])
D.add_facies([facies_1, facies_5])
D1.add_facies([facies_1])
D2.add_facies([facies_5])
C.add_facies([facies_4, facies_6])

# property model
cm_prop1 = gcm.CovModel3D(elem = [("spherical", {"w":0.1, "r":[10,10,10]}),
                                  ("cubic", {"w":0.1, "r":[15,15,15]})])
cm_prop2 = gcm.CovModel3D(elem = [("cubic", {"w":0.2, "r":[25, 25, 5]})])

list_facies = [facies_1, facies_2, facies_3, facies_4, facies_5, facies_6, facies_7]
list_covmodels = [cm_prop2, cm_prop1, cm_prop2, cm_prop1, cm_prop2, cm_prop1, cm_prop2]
means = [-4, -2, -6, -9, -6, -7, -19]
prop_model = ArchPy.base.Prop("K",
                              facies = list_facies,
                              covmodels = list_covmodels,
                                means = means,
                                int_method = "sgs",
                                vmin = -10,
                                vmax = -1
                                )
# Out:
# Facies basement added to unit A
# Facies Sand added to unit B
# Facies Gravel added to unit B
# Facies GM added to unit B
# Facies SM added to unit B
# Facies Sand added to unit D
# Facies SM added to unit D
# Facies Sand added to unit D1
# Facies SM added to unit D2
# Facies Clay added to unit C
# Facies Silt added to unit C

# %%
top = np.ones([ny,nx])*-6
bot = np.ones([ny,nx])*z0

# %%
T1 = Arch_table(name = "P1",seed=3)
T1.set_Pile_master(P1)
T1.add_grid(dimensions, spacing, origin, top=top,bot=bot, polygon=domain)
T1.add_prop(prop_model)
# Out:
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##
# Property K added

# %%
T1.compute_surf(1)
T1.compute_facies(1)
T1.compute_prop(1)
# Out:
# Boreholes not processed, fully unconditional simulations will be tempted
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# Discrepency in the orders for units A and B
# Changing orders for that they range from 1 to n
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04172873497009277 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02927374839782715 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028922080993652344 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0898892879486084 s
# ##########################
#
# ########## PILE PD ##########
# Pile PD: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02493453025817871 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.045865535736083984 s
# ##########################
#
#
# ### 0.2885403633117676: Total time elapsed for computing surfaces ###
#
# ### Unit D: facies simulation with SubPile method ####
# SubPile filling method, nothing happened
# Time elapsed 0.0 s
#
# ### Unit C: facies simulation with SIS method ####
# ### Unit C - realization 0 ###
# Only one facies covmodels for multiples facies, adapt sill to right proportions
# Time elapsed 1.03 s
#
# ### Unit B: facies simulation with SIS method ####
# ### Unit B - realization 0 ###
# Time elapsed 2.04 s
#
# ### Unit A: facies simulation with homogenous method ####
# ### Unit A - realization 0 ###
# Time elapsed 0.02 s
#
# ### Unit D2: facies simulation with homogenous method ####
# ### Unit D2 - realization 0 ###
# Time elapsed 0.01 s
#
# ### Unit D1: facies simulation with homogenous method ####
# ### Unit D1 - realization 0 ###
# Time elapsed 0.01 s
#
# ### 3.1: Total time elapsed for computing facies ###
# ### 1 K property models will be modeled ###
# ### 1 K models done

# %%
plt.imshow()

# %%
pv.set_jupyter_backend("static")

# %%
T1.plot_facies()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
T1.plot_prop("K")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
import flopy as fp
import ArchPy.ap_mf
from ArchPy.ap_mf import archpy2modflow, array2cellids

# %%
archpy_flow = archpy2modflow(T1, exe_name="../../../../../exe/mf6.exe", model_dir="reference")  # create the modflow model
archpy_flow.create_sim(grid_mode="layers", iu=0)  # create the simulation object and choose a certain discretization
archpy_flow.set_k("K", iu=0, ifa=0, ip=0, log=True)  # set the hydraulic conductivity
# Out:
# Simulation created
# To retrieve the simulation, use the get_sim() method

# %% [markdown]
# ### Construct modflow model

# %%
sim = archpy_flow.get_sim()
gwf = archpy_flow.get_gwf()

# %% [markdown]
# #### BC

# %%
# add BC at left and right on all layers
h1 = 1
h2 = 0
chd_data = []

a = np.zeros((gwf.modelgrid.nlay, gwf.modelgrid.nrow, gwf.modelgrid.ncol), dtype=bool)
a[:, :, 0] = 1
lst_chd = array2cellids(a, gwf.dis.idomain.array)
for cellid in lst_chd:
    chd_data.append((cellid, h1))

a = np.zeros((gwf.modelgrid.nlay, gwf.modelgrid.nrow, gwf.modelgrid.ncol), dtype=bool)
a[:, :, -1] = 1
lst_chd = array2cellids(a, gwf.dis.idomain.array)
for cellid in lst_chd:
    chd_data.append((cellid, h2))

chd = fp.mf6.ModflowGwfchd(gwf, stress_period_data=chd_data, save_flows=True)

# %% [markdown]
# #### Observations for inverse

# %%
obs_recarray = {
    "head_obs_ref.csv": [(("h1","HEAD",(3, 13, 25))), ("h2", "HEAD", (3, 25, 50)), ("h3", "HEAD", (3, 45, 80)), (("h4","HEAD",(3, 33, 110))), 
                         (("h5","HEAD",(3, 63, 130)))]
}
obs_package = fp.mf6.ModflowUtlobs(
    gwf,
    pname="head_obs",
    filename="{}.obs".format(gwf.name),
    digits=5,
    print_input=True,
    continuous=obs_recarray,
)

# %%
grid = gwf.modelgrid
plt.scatter(
    [grid.xcellcenters[cell[2][1], cell[2][2]] for cell in obs_recarray["head_obs_ref.csv"]],
    [grid.ycellcenters[cell[2][1], cell[2][2]] for cell in obs_recarray["head_obs_ref.csv"]],
    marker="o",
    color="red",
    label="Observation points",
)
gwf.modelgrid.plot(alpha=.3)

# %%
sim.write_simulation()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model test...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package oc...
#     writing package npf...
#     writing package chd_0...
# INFORMATION: maxbound in ('gwf6', 'chd', 'dimensions') changed to 549 based on size of stress_period_data
#     writing package head_obs...

# %%
sim.run_simulation()
# Out:
# FloPy is using the following executable to run the model: ..\..\..\..\..\..\exe\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.1 02/10/2025
#
#    MODFLOW 6 compiled Feb 14 2025 13:40:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/06/16 14:03:32
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2025/06/16 14:03:33
#  Elapsed run time:  1.116 Seconds
#
#  Normal termination of simulation.
# (True, [])

# %%
import copy
T1_org = copy.deepcopy(T1)

# %% [markdown]
# Simulations on other realizations
#
# first change Pile to have homogeneous units

# %%
# set f_method
for unit in T1.get_all_units():
    if unit.f_method == "SIS":
        d_fa = unit.dic_facies
        d_fa["f_method"] = "homogenous"
        unit.set_dic_facies(d_fa)
    
    # remove facies
    while len(unit.list_facies) > 0:
        unit.list_facies.pop()

# create a facies for each unit
facies_D2 = Facies(ID = 1, name="D2", color="yellow")
facies_D1 = Facies(ID = 2, name="D1", color="brown")
facies_C = Facies(ID = 3, name="C", color="blue")
facies_B = Facies(ID = 4, name="B", color="green")
facies_A = Facies(ID = 5, name="A", color="red")

D2.add_facies([facies_D2])
D1.add_facies([facies_D1])
C.add_facies([facies_C])
B.add_facies([facies_B])
A.add_facies([facies_A])

# set k values for each layer (new property)
# T1.rem_prop("K")  # remove the previous property model
# list_facies = [facies_D2, facies_D1, facies_C, facies_B, facies_A]
# means = [(-7, -4), (-4, -2), (-8, -5), (-4, -1), (-10, -10)]
# prop_model = ArchPy.base.Prop("K",
#                               facies = list_facies,
#                               covmodels = None,
#                                 means = means,
#                                 int_method = "homogenous_uniform",
#                                 vmin = -10,
#                                 vmax = -1
#                                 )
T1.rem_prop("K")  # remove the previous property model
list_facies = [facies_D2, facies_D1, facies_C, facies_B, facies_A]
means = [-6, -4, -7.25, -3.9, -10]
prop_model = ArchPy.base.Prop("K",
                              facies = list_facies,
                              covmodels = None,
                                means = means,
                                int_method = "homogenous",
                                vmin = -10,
                                vmax = -1
                                )
T1.add_prop(prop_model)
# Out:
# Facies D2 added to unit D2
# Facies D1 added to unit D1
# Facies C added to unit C
# Facies B added to unit B
# Facies A added to unit A
# Property K removed
# Property K added

# %%
T1.seed = int(4e6)

# %%
T1.process_bhs()
T1.compute_surf(50)
T1.compute_facies()
T1.compute_prop()
# Out:
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# Pile PD: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
# No borehole found - no hd extracted
# Boreholes not processed, fully unconditional simulations will be tempted
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02967238426208496 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026277542114257812 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028133153915405273 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1034705638885498 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.029398679733276367 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0272367000579834 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028217077255249023 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09113693237304688 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02884840965270996 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03625130653381348 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02913522720336914 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08468484878540039 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027249574661254883 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.025182247161865234 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030248165130615234 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09686946868896484 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024246692657470703 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02819991111755371 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028275489807128906 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10185503959655762 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027924060821533203 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027030467987060547 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02603888511657715 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09705781936645508 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02593088150024414 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0249330997467041 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029201745986938477 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09674239158630371 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024515628814697266 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.024933815002441406 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028105974197387695 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0827798843383789 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03736519813537598 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.029395580291748047 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02593088150024414 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09211897850036621 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025930166244506836 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02692866325378418 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026129722595214844 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09601855278015137 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025371074676513672 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027925968170166016 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029067039489746094 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08776664733886719 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026927709579467773 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027909517288208008 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029230833053588867 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10394859313964844 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025930404663085938 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028170108795166016 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029025793075561523 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09396505355834961 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02792525291442871 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027149438858032227 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02780008316040039 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10698318481445312 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027033329010009766 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02606487274169922 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026918888092041016 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10472226142883301 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027925968170166016 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.029919147491455078 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03381180763244629 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10380744934082031 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.029920339584350586 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03101944923400879 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.033025264739990234 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09585452079772949 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.029341936111450195 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027144193649291992 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030613183975219727 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10016703605651855 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0258791446685791 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02481985092163086 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.0339510440826416 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10164809226989746 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028997421264648438 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.045424699783325195 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.031226396560668945 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09886312484741211 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028096914291381836 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02749013900756836 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028774261474609375 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0948798656463623 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025255918502807617 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.025299787521362305 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.024318218231201172 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1055452823638916 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.037685394287109375 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03771829605102539 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.031213045120239258 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09055733680725098 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04192495346069336 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.04407358169555664 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03791689872741699 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1127009391784668 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024931907653808594 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0386807918548584 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.044656991958618164 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11071372032165527 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.11918830871582031 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.049889564514160156 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.0412440299987793 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11020255088806152 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.034552574157714844 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.033133506774902344 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02739882469177246 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1045374870300293 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04030299186706543 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03651261329650879 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.032144784927368164 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11741256713867188 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024116992950439453 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03264784812927246 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029814481735229492 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10940837860107422 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03609776496887207 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0291597843170166 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028195858001708984 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09170651435852051 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.036942481994628906 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02382183074951172 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029738664627075195 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10793757438659668 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.035375118255615234 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027362346649169922 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.025730371475219727 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10622596740722656 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02685689926147461 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026927709579467773 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030130863189697266 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11193013191223145 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03511238098144531 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0390169620513916 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.04876995086669922 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1223599910736084 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.05672788619995117 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.036572933197021484 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03550529479980469 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11307692527770996 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04221606254577637 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03490090370178223 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.037290334701538086 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10671710968017578 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0378115177154541 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0455021858215332 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.04432320594787598 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1017301082611084 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026116132736206055 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.029282808303833008 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03003239631652832 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12866640090942383 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04297041893005371 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027381420135498047 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02514934539794922 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12085962295532227 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026360511779785156 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.036447763442993164 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.043357133865356445 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1141359806060791 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04103350639343262 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.035263776779174805 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03824448585510254 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10617566108703613 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03540182113647461 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.036156415939331055 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03201127052307129 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10289239883422852 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.041298627853393555 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0405268669128418 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03392457962036133 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10846376419067383 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03867697715759277 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0339655876159668 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.055509328842163086 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1032559871673584 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.029491901397705078 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02855992317199707 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026259422302246094 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10643863677978516 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03348970413208008 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.031168222427368164 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.033347129821777344 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12121367454528809 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03865480422973633 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.06331706047058105 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.0498661994934082 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10419917106628418 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0281069278717041 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028900623321533203 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.031014680862426758 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10674500465393066 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03270578384399414 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0432436466217041 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.04259443283081055 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10272645950317383 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02616143226623535 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02393507957458496 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026927709579467773 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10697293281555176 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.030948162078857422 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.033489227294921875 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03672647476196289 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10905909538269043 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.04288315773010254 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027275562286376953 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03760933876037598 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09925651550292969 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028418302536010742 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026928186416625977 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.029920339584350586 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09574532508850098 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027927875518798828 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02785348892211914 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.036787986755371094 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10904812812805176 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027140140533447266 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027925729751586914 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03235149383544922 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09676194190979004 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02692580223083496 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028922557830810547 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028924226760864258 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10118985176086426 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025931119918823242 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028928279876708984 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.0274198055267334 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09774065017700195 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028921842575073242 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02918243408203125 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02991938591003418 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09583854675292969 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02713179588317871 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027163028717041016 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027876853942871094 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11075234413146973 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.036744117736816406 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02892780303955078 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02892303466796875 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09597063064575195 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02493572235107422 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027925729751586914 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030916929244995117 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10147643089294434 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028513431549072266 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02730274200439453 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028228044509887695 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08977413177490234 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0274202823638916 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.033293962478637695 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02930426597595215 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0905313491821289 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024601459503173828 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.025259017944335938 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028291702270507812 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09272193908691406 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026244640350341797 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026116371154785156 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02903294563293457 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11503148078918457 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0359039306640625 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.034818410873413086 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027021169662475586 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11722493171691895 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03335857391357422 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.040712594985961914 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.10643339157104492 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09805154800415039 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02986311912536621 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.024161100387573242 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030340194702148438 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11937499046325684 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02718043327331543 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028330564498901367 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.040528297424316406 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.11515116691589355 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03900313377380371 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.062253713607788086 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.04311728477478027 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09869980812072754 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.037497520446777344 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03814411163330078 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028148889541625977 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09952211380004883 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.03490710258483887 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03716158866882324 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.09109306335449219 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0970613956451416 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026026248931884766 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026925325393676758 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027925491333007812 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10595321655273438 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.040891408920288086 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.050135135650634766 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03490614891052246 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12702274322509766 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.05743861198425293 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.033095359802246094 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02875232696533203 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09672141075134277 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027242660522460938 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027245044708251953 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02523517608642578 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09081864356994629 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02880716323852539 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.0274808406829834 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026140213012695312 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10494518280029297 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027156591415405273 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02487039566040039 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03202223777770996 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08669209480285645 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02820134162902832 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026256799697875977 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030048608779907227 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10415959358215332 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026249170303344727 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026184797286987305 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03135085105895996 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10487508773803711 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026946306228637695 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.028078556060791016 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027039527893066406 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1059255599975586 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026057720184326172 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026884794235229492 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02729344367980957 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08686542510986328 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028987884521484375 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026928424835205078 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027956008911132812 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0848839282989502 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.027181148529052734 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.024936676025390625 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.024930477142333984 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08997941017150879 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02792644500732422 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027054786682128906 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027043581008911133 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0009968280792236328 s
#
# Time elapsed for getting domains 0.08887028694152832 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.023909568786621094 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027032136917114258 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03136324882507324 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.08776688575744629 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.0270388126373291 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027286291122436523 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026472806930541992 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09520268440246582 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026823043823242188 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.030025243759155273 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028017282485961914 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0999612808227539 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028048038482666016 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.027984619140625 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.03100109100341797 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.07192087173461914 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026141643524169922 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02787327766418457 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02702498435974121 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09409689903259277 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025136232376098633 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02597332000732422 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.026927709579467773 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10895276069641113 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02892327308654785 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.03126811981201172 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028923749923706055 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10480594635009766 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028546810150146484 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02875661849975586 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.025931835174560547 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10083889961242676 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024180889129638672 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026085376739501953 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02824115753173828 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1017305850982666 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.024932146072387695 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02679610252380371 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.02717137336730957 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09619998931884766 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.023934602737426758 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.025378942489624023 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028022050857543945 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.1047203540802002 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.02640247344970703 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.024147510528564453 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027328014373779297 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09877657890319824 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.028213024139404297 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.030415773391723633 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.030539512634277344 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09679555892944336 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.026249408721923828 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.026033401489257812 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.028238534927368164 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.10187029838562012 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.025906085968017578 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.02722334861755371 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.027318954467773438 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.09491682052612305 s
# ##########################
#
# ########## PILE PD ##########
# Pile PD: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.030654191970825195 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0504453182220459 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.027645349502563477 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.050426483154296875 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028763532638549805 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04732084274291992 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02689194679260254 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04596352577209473 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02611994743347168 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.051416635513305664 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.026181697845458984 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.045503854751586914 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.029234886169433594 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04333853721618652 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.026306867599487305 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04434347152709961 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028197288513183594 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.03836369514465332 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028242826461791992 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05555105209350586 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02515888214111328 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.03933835029602051 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028224706649780273 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05333256721496582 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.03496217727661133 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05385732650756836 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.03014659881591797 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.050864458084106445 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028180837631225586 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05598139762878418 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.029034852981567383 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.03988981246948242 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.027925491333007812 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.050992488861083984 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.030321598052978516 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05179786682128906 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.029919862747192383 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.050862789154052734 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02835249900817871 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.056847572326660156 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02692890167236328 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05285978317260742 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.028922080993652344 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.05406951904296875 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.027925491333007812 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04986739158630371 s
#
# #### COMPUTING SURFACE OF UNIT D1
# D1: time elapsed for computing surface 0.02692866325378418 s
#
# #### COMPUTING SURFACE OF UNIT D2
# D2: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04986572265625 s
#
# #### COMPUTING SURFACE OF UNIT D1
# ...
# ### Unit C - realization 85 ###
# ### Unit C - realization 86 ###
# ### Unit C - realization 87 ###
# ### Unit C - realization 88 ###
# ### Unit C - realization 89 ###
# ### Unit C - realization 90 ###
# ### Unit C - realization 91 ###
# ### Unit C - realization 92 ###
# ### Unit C - realization 93 ###
# ### Unit C - realization 94 ###
# ### Unit C - realization 95 ###
# ### Unit C - realization 96 ###
# ### Unit C - realization 97 ###
# ### Unit C - realization 98 ###
# ### Unit C - realization 99 ###
# Time elapsed 2.14 s
#
# ### Unit B: facies simulation with homogenous method ####
# ### Unit B - realization 0 ###
# ### Unit B - realization 1 ###
# ### Unit B - realization 2 ###
# ### Unit B - realization 3 ###
# ### Unit B - realization 4 ###
# ### Unit B - realization 5 ###
# ### Unit B - realization 6 ###
# ### Unit B - realization 7 ###
# ### Unit B - realization 8 ###
# ### Unit B - realization 9 ###
# ### Unit B - realization 10 ###
# ### Unit B - realization 11 ###
# ### Unit B - realization 12 ###
# ### Unit B - realization 13 ###
# ### Unit B - realization 14 ###
# ### Unit B - realization 15 ###
# ### Unit B - realization 16 ###
# ### Unit B - realization 17 ###
# ### Unit B - realization 18 ###
# ### Unit B - realization 19 ###
# ### Unit B - realization 20 ###
# ### Unit B - realization 21 ###
# ### Unit B - realization 22 ###
# ### Unit B - realization 23 ###
# ### Unit B - realization 24 ###
# ### Unit B - realization 25 ###
# ### Unit B - realization 26 ###
# ### Unit B - realization 27 ###
# ### Unit B - realization 28 ###
# ### Unit B - realization 29 ###
# ### Unit B - realization 30 ###
# ### Unit B - realization 31 ###
# ### Unit B - realization 32 ###
# ### Unit B - realization 33 ###
# ### Unit B - realization 34 ###
# ### Unit B - realization 35 ###
# ### Unit B - realization 36 ###
# ### Unit B - realization 37 ###
# ### Unit B - realization 38 ###
# ### Unit B - realization 39 ###
# ### Unit B - realization 40 ###
# ### Unit B - realization 41 ###
# ### Unit B - realization 42 ###
# ### Unit B - realization 43 ###
# ### Unit B - realization 44 ###
# ### Unit B - realization 45 ###
# ### Unit B - realization 46 ###
# ### Unit B - realization 47 ###
# ### Unit B - realization 48 ###
# ### Unit B - realization 49 ###
# ### Unit B - realization 50 ###
# ### Unit B - realization 51 ###
# ### Unit B - realization 52 ###
# ### Unit B - realization 53 ###
# ### Unit B - realization 54 ###
# ### Unit B - realization 55 ###
# ### Unit B - realization 56 ###
# ### Unit B - realization 57 ###
# ### Unit B - realization 58 ###
# ### Unit B - realization 59 ###
# ### Unit B - realization 60 ###
# ### Unit B - realization 61 ###
# ### Unit B - realization 62 ###
# ### Unit B - realization 63 ###
# ### Unit B - realization 64 ###
# ### Unit B - realization 65 ###
# ### Unit B - realization 66 ###
# ### Unit B - realization 67 ###
# ### Unit B - realization 68 ###
# ### Unit B - realization 69 ###
# ### Unit B - realization 70 ###
# ### Unit B - realization 71 ###
# ### Unit B - realization 72 ###
# ### Unit B - realization 73 ###
# ### Unit B - realization 74 ###
# ### Unit B - realization 75 ###
# ### Unit B - realization 76 ###
# ### Unit B - realization 77 ###
# ### Unit B - realization 78 ###
# ### Unit B - realization 79 ###
# ### Unit B - realization 80 ###
# ### Unit B - realization 81 ###
# ### Unit B - realization 82 ###
# ### Unit B - realization 83 ###
# ### Unit B - realization 84 ###
# ### Unit B - realization 85 ###
# ### Unit B - realization 86 ###
# ### Unit B - realization 87 ###
# ### Unit B - realization 88 ###
# ### Unit B - realization 89 ###
# ### Unit B - realization 90 ###
# ### Unit B - realization 91 ###
# ### Unit B - realization 92 ###
# ### Unit B - realization 93 ###
# ### Unit B - realization 94 ###
# ### Unit B - realization 95 ###
# ### Unit B - realization 96 ###
# ### Unit B - realization 97 ###
# ### Unit B - realization 98 ###
# ### Unit B - realization 99 ###
# Time elapsed 2.55 s
#
# ### Unit A: facies simulation with homogenous method ####
# ### Unit A - realization 0 ###
# ### Unit A - realization 1 ###
# ### Unit A - realization 2 ###
# ### Unit A - realization 3 ###
# ### Unit A - realization 4 ###
# ### Unit A - realization 5 ###
# ### Unit A - realization 6 ###
# ### Unit A - realization 7 ###
# ### Unit A - realization 8 ###
# ### Unit A - realization 9 ###
# ### Unit A - realization 10 ###
# ### Unit A - realization 11 ###
# ### Unit A - realization 12 ###
# ### Unit A - realization 13 ###
# ### Unit A - realization 14 ###
# ### Unit A - realization 15 ###
# ### Unit A - realization 16 ###
# ### Unit A - realization 17 ###
# ### Unit A - realization 18 ###
# ### Unit A - realization 19 ###
# ### Unit A - realization 20 ###
# ### Unit A - realization 21 ###
# ### Unit A - realization 22 ###
# ### Unit A - realization 23 ###
# ### Unit A - realization 24 ###
# ### Unit A - realization 25 ###
# ### Unit A - realization 26 ###
# ### Unit A - realization 27 ###
# ### Unit A - realization 28 ###
# ### Unit A - realization 29 ###
# ### Unit A - realization 30 ###
# ### Unit A - realization 31 ###
# ### Unit A - realization 32 ###
# ### Unit A - realization 33 ###
# ### Unit A - realization 34 ###
# ### Unit A - realization 35 ###
# ### Unit A - realization 36 ###
# ### Unit A - realization 37 ###
# ### Unit A - realization 38 ###
# ### Unit A - realization 39 ###
# ### Unit A - realization 40 ###
# ### Unit A - realization 41 ###
# ### Unit A - realization 42 ###
# ### Unit A - realization 43 ###
# ### Unit A - realization 44 ###
# ### Unit A - realization 45 ###
# ### Unit A - realization 46 ###
# ### Unit A - realization 47 ###
# ### Unit A - realization 48 ###
# ### Unit A - realization 49 ###
# ### Unit A - realization 50 ###
# ### Unit A - realization 51 ###
# ### Unit A - realization 52 ###
# ### Unit A - realization 53 ###
# ### Unit A - realization 54 ###
# ### Unit A - realization 55 ###
# ### Unit A - realization 56 ###
# ### Unit A - realization 57 ###
# ### Unit A - realization 58 ###
# ### Unit A - realization 59 ###
# ### Unit A - realization 60 ###
# ### Unit A - realization 61 ###
# ### Unit A - realization 62 ###
# ### Unit A - realization 63 ###
# ### Unit A - realization 64 ###
# ### Unit A - realization 65 ###
# ### Unit A - realization 66 ###
# ### Unit A - realization 67 ###
# ### Unit A - realization 68 ###
# ### Unit A - realization 69 ###
# ### Unit A - realization 70 ###
# ### Unit A - realization 71 ###
# ### Unit A - realization 72 ###
# ### Unit A - realization 73 ###
# ### Unit A - realization 74 ###
# ### Unit A - realization 75 ###
# ### Unit A - realization 76 ###
# ### Unit A - realization 77 ###
# ### Unit A - realization 78 ###
# ### Unit A - realization 79 ###
# ### Unit A - realization 80 ###
# ### Unit A - realization 81 ###
# ### Unit A - realization 82 ###
# ### Unit A - realization 83 ###
# ### Unit A - realization 84 ###
# ### Unit A - realization 85 ###
# ### Unit A - realization 86 ###
# ### Unit A - realization 87 ###
# ### Unit A - realization 88 ###
# ### Unit A - realization 89 ###
# ### Unit A - realization 90 ###
# ### Unit A - realization 91 ###
# ### Unit A - realization 92 ###
# ### Unit A - realization 93 ###
# ### Unit A - realization 94 ###
# ### Unit A - realization 95 ###
# ### Unit A - realization 96 ###
# ### Unit A - realization 97 ###
# ### Unit A - realization 98 ###
# ### Unit A - realization 99 ###
# Time elapsed 2.63 s
#
# ### Unit D2: facies simulation with homogenous method ####
# ### Unit D2 - realization 0 ###
# ### Unit D2 - realization 1 ###
# ### Unit D2 - realization 2 ###
# ### Unit D2 - realization 3 ###
# ### Unit D2 - realization 4 ###
# ### Unit D2 - realization 5 ###
# ### Unit D2 - realization 6 ###
# ### Unit D2 - realization 7 ###
# ### Unit D2 - realization 8 ###
# ### Unit D2 - realization 9 ###
# ### Unit D2 - realization 10 ###
# ### Unit D2 - realization 11 ###
# ### Unit D2 - realization 12 ###
# ### Unit D2 - realization 13 ###
# ### Unit D2 - realization 14 ###
# ### Unit D2 - realization 15 ###
# ### Unit D2 - realization 16 ###
# ### Unit D2 - realization 17 ###
# ### Unit D2 - realization 18 ###
# ### Unit D2 - realization 19 ###
# ### Unit D2 - realization 20 ###
# ### Unit D2 - realization 21 ###
# ### Unit D2 - realization 22 ###
# ### Unit D2 - realization 23 ###
# ### Unit D2 - realization 24 ###
# ### Unit D2 - realization 25 ###
# ### Unit D2 - realization 26 ###
# ### Unit D2 - realization 27 ###
# ### Unit D2 - realization 28 ###
# ### Unit D2 - realization 29 ###
# ### Unit D2 - realization 30 ###
# ### Unit D2 - realization 31 ###
# ### Unit D2 - realization 32 ###
# ### Unit D2 - realization 33 ###
# ### Unit D2 - realization 34 ###
# ### Unit D2 - realization 35 ###
# ### Unit D2 - realization 36 ###
# ### Unit D2 - realization 37 ###
# ### Unit D2 - realization 38 ###
# ### Unit D2 - realization 39 ###
# ### Unit D2 - realization 40 ###
# ### Unit D2 - realization 41 ###
# ### Unit D2 - realization 42 ###
# ### Unit D2 - realization 43 ###
# ### Unit D2 - realization 44 ###
# ### Unit D2 - realization 45 ###
# ### Unit D2 - realization 46 ###
# ### Unit D2 - realization 47 ###
# ### Unit D2 - realization 48 ###
# ### Unit D2 - realization 49 ###
# ### Unit D2 - realization 50 ###
# ### Unit D2 - realization 51 ###
# ### Unit D2 - realization 52 ###
# ### Unit D2 - realization 53 ###
# ### Unit D2 - realization 54 ###
# ### Unit D2 - realization 55 ###
# ### Unit D2 - realization 56 ###
# ### Unit D2 - realization 57 ###
# ### Unit D2 - realization 58 ###
# ### Unit D2 - realization 59 ###
# ### Unit D2 - realization 60 ###
# ### Unit D2 - realization 61 ###
# ### Unit D2 - realization 62 ###
# ### Unit D2 - realization 63 ###
# ### Unit D2 - realization 64 ###
# ### Unit D2 - realization 65 ###
# ### Unit D2 - realization 66 ###
# ### Unit D2 - realization 67 ###
# ### Unit D2 - realization 68 ###
# ### Unit D2 - realization 69 ###
# ### Unit D2 - realization 70 ###
# ### Unit D2 - realization 71 ###
# ### Unit D2 - realization 72 ###
# ### Unit D2 - realization 73 ###
# ### Unit D2 - realization 74 ###
# ### Unit D2 - realization 75 ###
# ### Unit D2 - realization 76 ###
# ### Unit D2 - realization 77 ###
# ### Unit D2 - realization 78 ###
# ### Unit D2 - realization 79 ###
# ### Unit D2 - realization 80 ###
# ### Unit D2 - realization 81 ###
# ### Unit D2 - realization 82 ###
# ### Unit D2 - realization 83 ###
# ### Unit D2 - realization 84 ###
# ### Unit D2 - realization 85 ###
# ### Unit D2 - realization 86 ###
# ### Unit D2 - realization 87 ###
# ### Unit D2 - realization 88 ###
# ### Unit D2 - realization 89 ###
# ### Unit D2 - realization 90 ###
# ### Unit D2 - realization 91 ###
# ### Unit D2 - realization 92 ###
# ### Unit D2 - realization 93 ###
# ### Unit D2 - realization 94 ###
# ### Unit D2 - realization 95 ###
# ### Unit D2 - realization 96 ###
# ### Unit D2 - realization 97 ###
# ### Unit D2 - realization 98 ###
# ### Unit D2 - realization 99 ###
# Time elapsed 1.97 s
#
# ### Unit D1: facies simulation with homogenous method ####
# ### Unit D1 - realization 0 ###
# ### Unit D1 - realization 1 ###
# ### Unit D1 - realization 2 ###
# ### Unit D1 - realization 3 ###
# ### Unit D1 - realization 4 ###
# ### Unit D1 - realization 5 ###
# ### Unit D1 - realization 6 ###
# ### Unit D1 - realization 7 ###
# ### Unit D1 - realization 8 ###
# ### Unit D1 - realization 9 ###
# ### Unit D1 - realization 10 ###
# ### Unit D1 - realization 11 ###
# ### Unit D1 - realization 12 ###
# ### Unit D1 - realization 13 ###
# ### Unit D1 - realization 14 ###
# ### Unit D1 - realization 15 ###
# ### Unit D1 - realization 16 ###
# ### Unit D1 - realization 17 ###
# ### Unit D1 - realization 18 ###
# ### Unit D1 - realization 19 ###
# ### Unit D1 - realization 20 ###
# ### Unit D1 - realization 21 ###
# ### Unit D1 - realization 22 ###
# ### Unit D1 - realization 23 ###
# ### Unit D1 - realization 24 ###
# ### Unit D1 - realization 25 ###
# ### Unit D1 - realization 26 ###
# ### Unit D1 - realization 27 ###
# ### Unit D1 - realization 28 ###
# ### Unit D1 - realization 29 ###
# ### Unit D1 - realization 30 ###
# ### Unit D1 - realization 31 ###
# ### Unit D1 - realization 32 ###
# ### Unit D1 - realization 33 ###
# ### Unit D1 - realization 34 ###
# ### Unit D1 - realization 35 ###
# ### Unit D1 - realization 36 ###
# ### Unit D1 - realization 37 ###
# ### Unit D1 - realization 38 ###
# ### Unit D1 - realization 39 ###
# ### Unit D1 - realization 40 ###
# ### Unit D1 - realization 41 ###
# ### Unit D1 - realization 42 ###
# ### Unit D1 - realization 43 ###
# ### Unit D1 - realization 44 ###
# ### Unit D1 - realization 45 ###
# ### Unit D1 - realization 46 ###
# ### Unit D1 - realization 47 ###
# ### Unit D1 - realization 48 ###
# ### Unit D1 - realization 49 ###
# ### Unit D1 - realization 50 ###
# ### Unit D1 - realization 51 ###
# ### Unit D1 - realization 52 ###
# ### Unit D1 - realization 53 ###
# ### Unit D1 - realization 54 ###
# ### Unit D1 - realization 55 ###
# ### Unit D1 - realization 56 ###
# ### Unit D1 - realization 57 ###
# ### Unit D1 - realization 58 ###
# ### Unit D1 - realization 59 ###
# ### Unit D1 - realization 60 ###
# ### Unit D1 - realization 61 ###
# ### Unit D1 - realization 62 ###
# ### Unit D1 - realization 63 ###
# ### Unit D1 - realization 64 ###
# ### Unit D1 - realization 65 ###
# ### Unit D1 - realization 66 ###
# ### Unit D1 - realization 67 ###
# ### Unit D1 - realization 68 ###
# ### Unit D1 - realization 69 ###
# ### Unit D1 - realization 70 ###
# ### Unit D1 - realization 71 ###
# ### Unit D1 - realization 72 ###
# ### Unit D1 - realization 73 ###
# ### Unit D1 - realization 74 ###
# ### Unit D1 - realization 75 ###
# ### Unit D1 - realization 76 ###
# ### Unit D1 - realization 77 ###
# ### Unit D1 - realization 78 ###
# ### Unit D1 - realization 79 ###
# ### Unit D1 - realization 80 ###
# ### Unit D1 - realization 81 ###
# ### Unit D1 - realization 82 ###
# ### Unit D1 - realization 83 ###
# ### Unit D1 - realization 84 ###
# ### Unit D1 - realization 85 ###
# ### Unit D1 - realization 86 ###
# ### Unit D1 - realization 87 ###
# ### Unit D1 - realization 88 ###
# ### Unit D1 - realization 89 ###
# ### Unit D1 - realization 90 ###
# ### Unit D1 - realization 91 ###
# ### Unit D1 - realization 92 ###
# ### Unit D1 - realization 93 ###
# ### Unit D1 - realization 94 ###
# ### Unit D1 - realization 95 ###
# ### Unit D1 - realization 96 ###
# ### Unit D1 - realization 97 ###
# ### Unit D1 - realization 98 ###
# ### Unit D1 - realization 99 ###
# Time elapsed 1.93 s
#
# ### 11.24: Total time elapsed for computing facies ###
# ### 100 K property models will be modeled ###
# ### 1 K models done
# ### 2 K models done
# ### 3 K models done
# ### 4 K models done
# ### 5 K models done
# ### 6 K models done
# ### 7 K models done
# ### 8 K models done
# ### 9 K models done
# ### 10 K models done
# ### 11 K models done
# ### 12 K models done
# ### 13 K models done
# ### 14 K models done
# ### 15 K models done
# ### 16 K models done
# ### 17 K models done
# ### 18 K models done
# ### 19 K models done
# ### 20 K models done
# ### 21 K models done
# ### 22 K models done
# ### 23 K models done
# ### 24 K models done
# ### 25 K models done
# ### 26 K models done
# ### 27 K models done
# ### 28 K models done
# ### 29 K models done
# ### 30 K models done
# ### 31 K models done
# ### 32 K models done
# ### 33 K models done
# ### 34 K models done
# ### 35 K models done
# ### 36 K models done
# ### 37 K models done
# ### 38 K models done
# ### 39 K models done
# ### 40 K models done
# ### 41 K models done
# ### 42 K models done
# ### 43 K models done
# ### 44 K models done
# ### 45 K models done
# ### 46 K models done
# ### 47 K models done
# ### 48 K models done
# ### 49 K models done
# ### 50 K models done
# ### 51 K models done
# ### 52 K models done
# ### 53 K models done
# ### 54 K models done
# ### 55 K models done
# ### 56 K models done
# ### 57 K models done
# ### 58 K models done
# ### 59 K models done
# ### 60 K models done
# ### 61 K models done
# ### 62 K models done
# ### 63 K models done
# ### 64 K models done
# ### 65 K models done
# ### 66 K models done
# ### 67 K models done
# ### 68 K models done
# ### 69 K models done
# ### 70 K models done
# ### 71 K models done
# ### 72 K models done
# ### 73 K models done
# ### 74 K models done
# ### 75 K models done
# ### 76 K models done
# ### 77 K models done
# ### 78 K models done
# ### 79 K models done
# ### 80 K models done
# ### 81 K models done
# ### 82 K models done
# ### 83 K models done
# ### 84 K models done
# ### 85 K models done
# ### 86 K models done
# ### 87 K models done
# ### 88 K models done
# ### 89 K models done
# ### 90 K models done
# ### 91 K models done
# ### 92 K models done
# ### 93 K models done
# ### 94 K models done
# ### 95 K models done
# ### 96 K models done
# ### 97 K models done
# ### 98 K models done
# ### 99 K models done
# ### 100 K models done

# %%
T1.plot_prop("K", 6)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
lst_obs = [("h1","HEAD", (3, 13, 25)), ("h2", "HEAD", (3, 25, 50)), ("h3", "HEAD", (3, 45, 80)),
           ("h4","HEAD", (3, 33, 110)), ("h5","HEAD", (3, 63, 130))]

n_obs = len(lst_obs)

# %%
def run_member(iu):

    sim = archpy_flow.get_sim()

    # change directory for the worker
    archpy_flow.set_model_dir(f"worker{iu}")
    import shutil  # copy content from reference directory to worker directory
    shutil.copytree("reference", f"worker{iu}", dirs_exist_ok=True)
    
    # change grid to the new surfaces
    archpy_flow.set_grid_layers_mode(iu=iu)

    gwf = archpy_flow.get_gwf()
    gwf.dis.write()

    # CHD
    gwf.chd.remove()
    # BC# add BC at left and right on all layers
    h1 = 1
    h2 = 0
    chd_data = []

    a = np.zeros((gwf.modelgrid.nlay, gwf.modelgrid.nrow, gwf.modelgrid.ncol), dtype=bool)
    a[:, :, 0] = 1
    lst_chd = array2cellids(a, gwf.dis.idomain.array)
    for cellid in lst_chd:
        chd_data.append((cellid, h1))

    a = np.zeros((gwf.modelgrid.nlay, gwf.modelgrid.nrow, gwf.modelgrid.ncol), dtype=bool)
    a[:, :, -1] = 1
    lst_chd = array2cellids(a, gwf.dis.idomain.array)
    for cellid in lst_chd:
        chd_data.append((cellid, h2))

    chd = fp.mf6.ModflowGwfchd(gwf, stress_period_data=chd_data, save_flows=True, maxbound=len(chd_data))
    chd.write()

    gwf.obs.remove()

    # lst_obs =  [("h1","HEAD", (3, 13, 25)), ("h2", "HEAD", (3, 25, 50)), ("h3", "HEAD", (3, 45, 80)),
    #             ("h4","HEAD", (3, 33, 110)), ("h5","HEAD", (3, 63, 130))]
    new_lst_obs = []
    # check in active cells
    idomain = gwf.dis.idomain.array
    for cell in lst_obs:
        cell_coord = cell[2]
        # print(idomain[cell_coord])
        if idomain[cell_coord] != 1:
            # print("asdfasdf")
            il, ir, ic = cell_coord
            if idomain[il+1, ir, ic] == 1:
                new_cell = (il+1, ir, ic)
                print("modif")
            elif idomain[il-1, ir, ic] == 1:
                new_cell = (il - 1, ir, ic)
                print("modif")
            else:
                new_cell = cell[2]
        else:
            new_cell = cell[2]

        new_obs = (cell[0], cell[1], new_cell)
        new_lst_obs.append(new_obs)

    obs_recarray = {
        f"head_obs{iu}.csv": new_lst_obs
    }
    
    obs_package = fp.mf6.ModflowUtlobs(
        gwf,
        pname="head_obs",
        filename="{}.obs".format(gwf.name),
        digits=5,
        print_input=True,
        continuous=obs_recarray,
    )
    obs_package.write()

    # adapt OC package to not write budget
    gwf.remove_package("OC")
    oc = fp.mf6.ModflowGwfoc(gwf, head_filerecord='{}.hds'.format(gwf.name),
                            saverecord=[('HEAD', 'LAST')],
                            printrecord=[('BUDGET', 'ALL')])
    oc.write()

    # set new conductivity
    archpy_flow.set_k("K", iu=iu, ifa=0, ip=0, log=True, average_facies=False)  # set the hydraulic conductivity
    gwf.npf.write()  # write the npf package with the new conductivity

    # run the model
    sim.run_simulation(silent=True)

    # transfer head_obs to workers_results folder
    if not os.path.exists("workers_results"):
        os.makedirs("workers_results")

    shutil.copy(f"worker{iu}/head_obs{iu}.csv", "workers_results/head_obs{}.csv".format(iu))

    # remove the worker directory
    shutil.rmtree(f"worker{iu}")

# %%
# remove existing worker directory
# import shutil
# list_dir = os.listdir(".")
# for d in list_dir:
#     if d.startswith("worker"):
#         shutil.rmtree(d)

# %%
n_members = T1.nreal_units
n_layers = 6
n_it = 1

# %%
def run_all_members(params):

    # add new surfaces to ArchPy table
    surfaces_by_piles = {}
    surfaces_by_piles["P1"] = params.reshape(n_members, n_layers, ny, nx)[:, :4]
    surfaces_by_piles["PD"] = params.reshape(n_members, n_layers, ny, nx)[:, 4:]

    # unit
    archpy_flow.T1.define_domains(surfaces_by_piles)
    # facies
    archpy_flow.T1.compute_facies()
    # prop
    archpy_flow.T1.compute_prop()

    # run members
    for i in range(n_members):
        run_member(i)

    # get observations
    h_all = pd.DataFrame()
    for i in range(n_members):
        h = pd.read_csv(f"workers_results/head_obs{i}.csv", index_col=0)
        if h.shape[0] == 1:
            h_all = pd.concat([h_all, h], axis=0)
    
    obs = h_all.values
    return obs, params

# %%
for i in range(n_members):
    run_member(i)
# Out:
# Model directory set to worker0
# Model directory set to worker1
# Model directory set to worker2
# Model directory set to worker3
# Model directory set to worker4
# Model directory set to worker5
# Model directory set to worker6
# Model directory set to worker7
# Model directory set to worker8
# Model directory set to worker9
# Model directory set to worker10
# Model directory set to worker11
# Model directory set to worker12
# Model directory set to worker13
# Model directory set to worker14
# Model directory set to worker15
# Model directory set to worker16
# Model directory set to worker17
# modif
# Model directory set to worker18
# Model directory set to worker19
# Model directory set to worker20
# Model directory set to worker21
# Model directory set to worker22
# Model directory set to worker23
# Model directory set to worker24
# Model directory set to worker25
# modif
# Model directory set to worker26
# Model directory set to worker27
# modif
# Model directory set to worker28
# Model directory set to worker29
# Model directory set to worker30
# Model directory set to worker31
# Model directory set to worker32
# Model directory set to worker33
# Model directory set to worker34
# Model directory set to worker35
# Model directory set to worker36
# Model directory set to worker37
# Model directory set to worker38
# Model directory set to worker39
# Model directory set to worker40
# Model directory set to worker41
# Model directory set to worker42
# Model directory set to worker43
# Model directory set to worker44
# Model directory set to worker45
# Model directory set to worker46
# Model directory set to worker47
# Model directory set to worker48
# Model directory set to worker49

# %%
#

# %%
import pandas as pd
h_all = pd.DataFrame()
for i in range(n_members):
    h = pd.read_csv(f"workers_results/head_obs{i}.csv", index_col=0)
    if h.shape[0] == 1:
        h_all = pd.concat([h_all, h], axis=0)

h_obs_ref = pd.read_csv("reference/head_obs_ref.csv", index_col=0)

# %%
# loop ESMDA
def Cov_matrix_RV(X,Y):
    mu_X = np.mean(X, axis=0)
    mu_Y = np.mean(Y, axis=0)
    return np.dot((X-mu_X).T,(Y-mu_Y))/X.shape[0]

# get params
params = np.concatenate((T1.Geol.org_surfaces_by_piles["P1"].reshape(n_members, -1), T1.Geol.org_surfaces_by_piles["PD"].reshape(n_members, -1)), axis=1)
# surfaces = list(surfaces.values())[0]

# %%
T1.Geol.org_surfaces_by_piles["PD"].reshape(n_members, -1).shape
# Out:
# (50, 39200)

# %%
ly = [cell[2][1] for cell in lst_obs]
lx = [cell[2][2] for cell in lst_obs]

# %%
#build localization matrix
def Gaspari_cohn(v, L): #function to calculate weights
    
    v_copy = v.copy()
    v = v.copy()
    r = v/L
    m1 = (v_copy >= 0) & (v_copy <= L)
    v[m1] = -0.25*r[m1]**5+0.5*r[m1]**4+(5/8)*r[m1]**3-(5/3)*r[m1]**2+1
    
    m2 = (v_copy > L) & (v_copy <= 2*L)
    v[m2] = (1/12)*r[m2]**5-0.5*r[m2]**4+(5/8)*r[m2]**3+(5/3)*r[m2]**2-5*r[m2]+4-(2/3)*r[m2]**(-1)
    
    m3 = v_copy > 2*L
    v[m3] = 0
    return v

# calculate distance btw points
xg = gwf.modelgrid.xcellcenters[0,:]
yg = gwf.modelgrid.ycellcenters[:,0]
M_dist = np.zeros([n_obs, ny, nx])
i_obs = 0
for ir, ic in zip(ly, lx):

    obs_xy = (xg[ic], yg[ir])
    for ix in range(xg.shape[0]):
        for iy in range(yg.shape[0]):
            M_dist[i_obs,iy,ix] = np.sqrt((xg[ix] - obs_xy[0])**2 + (yg[iy] - obs_xy[1])**2)
    
    i_obs += 1

weights = Gaspari_cohn(M_dist, L=70)

# assemble localization matrix
n_measures = 1  # number of measures by observation point
LM = np.zeros([])
for w in weights:
    
    m = np.dot(w.flatten().reshape(-1,1), np.ones([1, n_measures]))  # expand multiplication matrix to size of nobs
    # m = np.repeat(m, n_layers, axis=0)
    m = np.vstack([m]*n_layers)
    if LM.shape == ():
        LM = m
    else:
        LM = np.concatenate([LM, m],axis=1)

# %%
plt.imshow((LM[:, 0]).reshape(6, ny, nx)[0])

# %%
n_it = 3
error_h = 0.001

## start iterations ##
obs = h_all.values
params = params
obs_ref = np.array(h_obs_ref).reshape(-1)

# update #

all_obs = []
all_obs.append(obs.copy())
all_params = []
all_params.append(params.copy())

alpha = n_it

# error matrix
Cerr = np.diag(error_h*np.ones([len(obs_ref)]))

# %%
# params_org = params.copy()

# %%
# nmembers = obs.shape[0]
# CkMD = Cov_matrix_RV(params, obs)
# CkDD = Cov_matrix_RV(obs, obs)

# #compute kalman gain
# K = np.dot(CkMD, np.linalg.inv(CkDD+alpha*Cerr))
# if np.isnan(K).any():
#     print("error, nan occured")
# K *= LM

# for im in range(nmembers):
#     B = (obs_ref + np.sqrt(alpha) * np.dot(Cerr**0.5, np.random.normal(size=obs_ref.shape))) - obs[im]

#     param_update = np.dot(K, B)
#     params[im] += param_update

# %%
# # add new surfaces to ArchPy table
# surfaces_by_piles = {}
# surfaces_by_piles["P1"] = params.reshape(n_members, n_layers, ny, nx)[:, :4]
# surfaces_by_piles["PD"] = params.reshape(n_members, n_layers, ny, nx)[:, 4:]

# # unit
# archpy_flow.T1.define_domains(surfaces_by_piles)
# # facies
# archpy_flow.T1.compute_facies()
# # prop
# archpy_flow.T1.compute_prop()

# %%
# # run members
# for i in range(n_members):
#     run_member(i)

# %%
# # get observations
# h_all = pd.DataFrame()
# for i in range(n_members):
#     h = pd.read_csv(f"workers_results/head_obs{i}.csv", index_col=0)
#     if h.shape[0] == 1:
#         h_all = pd.concat([h_all, h], axis=0)

# obs = h_all.values

# %%
np.random.seed(1312)

# %%
for it in range(0, n_it):

    nmembers = obs.shape[0]
    CkMD = Cov_matrix_RV(params, obs)
    CkDD = Cov_matrix_RV(obs, obs)
    
    #compute kalman gain
    K = np.dot(CkMD, np.linalg.inv(CkDD+alpha*Cerr))
    if np.isnan(K).any():
        print("error, nan occured")
        break
    K *= LM
    
    for im in range(nmembers):
        B = (obs_ref + np.sqrt(alpha) * np.dot(Cerr**0.5, np.random.normal(size=obs_ref.shape))) - obs[im]

        param_update = np.dot(K, B)
        params[im] += param_update
    print("members updated")
    
    ob,pa = run_all_members(params)
    obs = np.array(ob)
    params = np.array(pa)
    
    # store values
    all_obs.append(obs.copy())
    all_params.append(params.copy())
    
    print("Iteration {} finished".format(it+1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 12
#      10     print("error, nan occured")
#      11     break
# ---> 12 K *= LM
#      14 for im in range(nmembers):
#      15     B = (obs_ref + np.sqrt(alpha) * np.dot(Cerr**0.5, np.random.normal(size=obs_ref.shape))) - obs[im]
#
# ValueError: operands could not be broadcast together with shapes (117600,5) (58800,5) (117600,5)

# %%
# compare results
h_ref = pd.read_csv("reference/head_obs_ref.csv", index_col=0)

it = 0
h_all = pd.DataFrame()
for i in range(n_members):
    if h.shape[0] == 1:
        plt.scatter(h_ref.values, all_obs[it][i], alpha=1, c="lightblue", zorder=1)
        h_all = pd.concat([h_all, h], axis=0)

# # plot mean
# h_mean = h_all.groupby(h_all.index).mean()
plt.scatter(h_ref.values, np.mean(all_obs[it], axis=0), color="red", label="Mean from workers")


plt.plot([0, 1], [0, 1], color="black", linestyle="--")
plt.xlabel("Reference head")
plt.ylabel("Head from worker")
# Out:
# Text(0, 0.5, 'Head from worker')

# %%
# compare results
h_ref = pd.read_csv("reference/head_obs_ref.csv", index_col=0)

it = -1
h_all = pd.DataFrame()
for i in range(n_members):
    if h.shape[0] == 1:
        plt.scatter(h_ref.values, all_obs[it][i], alpha=1, c="lightblue", zorder=1)
        h_all = pd.concat([h_all, h], axis=0)

# # plot mean
# h_mean = h_all.groupby(h_all.index).mean()
plt.scatter(h_ref.values, np.mean(all_obs[it], axis=0), color="red", label="Mean from workers")


plt.plot([0, 1], [0, 1], color="black", linestyle="--")
plt.xlabel("Reference head")
plt.ylabel("Head from worker")
# Out:
# Text(0, 0.5, 'Head from worker')

# %%
rmse = np.sqrt(np.mean((all_obs[-1] - h_ref.values)**2))
rmse
# Out:
# 0.046945731397518974

# %%
plt.plot(np.sqrt(np.mean((np.array(all_obs) - h_ref.values)**2, axis=(1, 2))))
plt.xlabel("Iteration")
plt.ylabel("RMSE")
# Out:
# Text(0, 0.5, 'RMSE')

# %%
irow = 40

iter = 0
ilay = 3
arr = all_params[iter].reshape(n_members, n_layers, ny, nx)[:, :4][:, ilay]
# plt.plot(arr[:, 20].T, color="lightgrey", alpha=.3)
plt.plot(np.mean(arr[:, irow], axis=0).T, color="grey", zorder=10)
plt.fill_between(np.arange(nx),
                 np.mean(arr[:, irow], axis=0) - 2*np.std(arr[:, irow], axis=0),
                 np.mean(arr[:, irow], axis=0) + 2*np.std(arr[:, irow], axis=0),
                 color="lightgrey", alpha=.5, zorder=5)
iter = -1
arr = all_params[iter].reshape(n_members, n_layers, ny, nx)[:, :4][:, ilay]
plt.plot(arr[:, irow].T, color="lightblue", alpha=.3)
plt.plot(np.mean(arr[:, irow], axis=0).T, color="blue", zorder=10)
# plt.fill_between(np.arange(nx),
#                  np.mean(arr[:, irow], axis=0) - 2*np.std(arr[:, irow], axis=0),
#                  np.mean(arr[:, irow], axis=0) + 2*np.std(arr[:, irow], axis=0),
#                  color="lightblue", alpha=.5, zorder=5)

plt.plot(T1_org.Geol.org_surfaces_by_piles["P1"][0, ilay, irow], zorder=100, c="k")

# %%
plt.imshow(T1_org.Geol.org_surfaces_by_piles["P1"][0, ilay])
plt.show()

iter = -1
arr = all_params[iter].reshape(n_members, n_layers, ny, nx)[:, :4][:, ilay]
plt.imshow(np.mean(arr[:], axis=0))

# %%
from flopy.export.vtk import Vtk

vert_exag = 3
vtk = Vtk(model=gwf, binary=False, vertical_exageration=vert_exag, smooth=True)
vtk.add_model(gwf)

head = gwf.output.head().get_data()
vtk.add_array(head, name="head")
gwf_mesh = vtk.to_pyvista()

ghosts = np.argwhere(gwf_mesh["idomain"] == 0)
gwf_mesh.remove_cells(ghosts, inplace=True)
ghosts = np.argwhere(gwf_mesh["head"] > 1)
gwf_mesh.remove_cells(ghosts, inplace=True)

pl = pv.Plotter(notebook=True)
pl.add_mesh(gwf_mesh, opacity=1, show_edges=True, scalars="head", cmap="viridis", clim=[0, 1], edge_opacity=0.3)
pl.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

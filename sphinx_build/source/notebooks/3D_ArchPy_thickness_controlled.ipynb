# %% [markdown]
# # Unit Thickness controlled
#
# This notebook presents a 3D synthetic model of ArchPy and demonstrate the capabilities to constrain units by thickness.
#
# No facies or property modeling here in order to keep the notebook short

# %%
import numpy as np
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
import geone
import geone.covModel as gcm
import geone.imgplot3d as imgplt3
import pyvista as pv
pv.set_jupyter_backend('static')
import sys

#For loading ArchPy, the path where ArchPy is must be added with sys
sys.path.append("../../")
#my modules
from ArchPy.base import * #ArchPy main functions 
from ArchPy.tpgs import * #Truncated plurigaussians

# %% [markdown]
# First defining necessary stratigraphic piles (same as in the 3D_archpy_example)

# %%
PB = Pile(name = "PB",seed=1)
P1 = Pile(name="P1",seed=1)

# %% [markdown]
# Dimensions of the grid

# %%
#grid
sx = 1.5
sy = 1.5
sz = .15
x1 = 20
y1 = 10
z1 = -6
x0 = 0
y0 = 0
z0 = -15
nx = 133
ny = 67
nz = 62


dimensions = (nx, ny, nz)
spacing = (sx, sy, sz)
origin = (x0, y0, z0)

# %% [markdown]
# The thickness constraint is defined here, when units are setup. To enforce a specific thickness to a unit, you can simply pass the key "thickness" to surface dictionary a particular unit and put the desired thickness as value

# %% [markdown]
# ## Pile

# %%
#units covmodel
covmodelD = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[60,60]})])
covmodelC = gcm.CovModel2D(elem=[('cubic', {'w':0.2, 'r':[80,80]})])
covmodelB = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[60,60]})])
covmodel_er = gcm.CovModel2D(elem=[('spherical', {'w':1, 'r':[100,100]})])

## facies covmodel
# covmodel_SIS_C = gcm.CovModel3D(elem=[("exponential",{"w":.25,"r":[10,10,3]})],alpha=0,name="vario_SIS") # input variogram
# covmodel_SIS_D = gcm.CovModel3D(elem=[("exponential",{"w":.25,"r":[5,5,5]})],alpha=0,name="vario_SIS") # input variogram
# lst_covmodelC=[covmodel_SIS_C] # list of covmodels to pass at the function
# lst_covmodelD=[covmodel_SIS_D]


#create Lithologies 
dic_s_D = {"int_method" : "grf_ineq","covmodel" : covmodelD}
dic_f_D = {"f_method":"homogenous"}
D = Unit(name="D",order=1,ID = 1,color="gold",contact="onlap",surface=Surface(contact="onlap",dic_surf=dic_s_D)
         ,dic_facies=dic_f_D)

dic_s_C = {"int_method" : "grf_ineq","covmodel" : covmodelC}
dic_f_C = {"f_method":"homogenous"}
C = Unit(name="C",order=2,ID = 2,color="blue",contact="onlap",dic_facies=dic_f_C,surface=Surface(dic_surf=dic_s_C,contact="onlap"))

dic_s_er2 = {"int_method" : "grf","covmodel" : covmodel_er}
erosion2 = Surface(dic_surf=dic_s_er2, contact="erode")
#er2 = Unit(name="erosion2",ID = 4, order=4,contact="erode",color="black",surface=Surface(dic_surf = dic_s_er2,contact="erode"))         

dic_s_B = {"int_method" : "grf_ineq","covmodel" : covmodelB, "thickness":2}
dic_f_B = {"f_method":"SubPile","SubPile":PB}
B = Unit(name="B",order=3,ID = 3,color="green",contact="onlap",dic_facies=dic_f_B,surface=Surface(contact="onlap",dic_surf=dic_s_B))

dic_s_A = {"int_method":"grf_ineq","covmodel": covmodelB}
dic_f_A = {"f_method":"homogenous"}
A = Unit(name="A",order=5,ID = 5,color="red",contact="onlap",dic_facies=dic_f_A,surface=Surface(dic_surf = dic_s_A,contact="onlap"))

#Master pile
P1.add_unit([D,C,B,A])

# PB
ds_B3 = {"int_method":"grf_ineq","covmodel":covmodelB}
dic_f_A = {"f_method":"homogenous"}
B3 = Unit(name = "B3",order=1,ID = 6,color="forestgreen",surface=Surface(dic_surf=ds_B3,contact="onlap"),dic_facies=df_B3)

ds_B2 = {"int_method":"grf_ineq","covmodel":covmodelB}
dic_f_A = {"f_method":"homogenous"}
B2 = Unit(name = "B2",order=2,ID = 7,color="limegreen",surface=Surface(dic_surf=ds_B2,contact="erode"),dic_facies=df_B2)

ds_B1 = {"int_method":"grf_ineq","covmodel":covmodelB}
dic_f_A = {"f_method":"homogenous"}
B1 = Unit(name = "B1",order=3, ID = 8,color="palegreen",surface=Surface(dic_surf=ds_B1,contact="onlap"),dic_facies=df_B1)

## Subpile
PB.add_unit([B3,B2,B1])
# Out:
# Unit D: Surface added for interpolation
# Unit C: Surface added for interpolation
# Unit B: Surface added for interpolation
# Unit A: Surface added for interpolation
# Stratigraphic unit D added ✅
# Stratigraphic unit C added ✅
# Stratigraphic unit B added ✅
# Stratigraphic unit A added ✅
# Unit B3: Surface added for interpolation
# Unit B2: Surface added for interpolation
# Unit B1: Surface added for interpolation
# Stratigraphic unit B3 added ✅
# Stratigraphic unit B2 added ✅
# Stratigraphic unit B1 added ✅

# %%
top = np.ones([ny,nx])*-6
bot = np.ones([ny,nx])*z0

# %% [markdown]
# ## Boreholes

# %%
#logs strati
log_strati1 = [(C,-6.01),(B3,-8),(B2,-9),(B1,-9.5),(A,-10)]
log_strati2 = [(C,-6.01),(B3,-8.5),(B2,-9.5),(A,-10.5)]
log_strati3 = [(D,-6.01),(B3,-8),(B2,-8.5),(B1,-9.5),(A,-10.5)]
log_strati4 = [(D,-6.01),(B3,-9),(B2,-10),(A,-11)]
log_strati5 = [(D,-6.01),(C,-10),(A,-12)]
log_strati6 = [(D,-6.01),(A,-9)]

#create boreholes
bh1 = borehole("b1",1,x=10*1,y=10*5,z=log_strati1[0][1],depth =9,log_strati=log_strati1,log_facies=log_facies1)
bh2 = borehole("b2",2,x=10*3,y=10*2,z=log_strati2[0][1],depth =8,log_strati=log_strati2,log_facies=log_facies2)
bh3 = borehole("b3",3,x=10*5,y=10*6,z=log_strati3[0][1],depth =7,log_strati=log_strati3,log_facies=log_facies3)
bh4 = borehole("b4",4,x=10*10,y=10*1,z=log_strati4[0][1],depth =8,log_strati=log_strati4,log_facies=log_facies4)
bh5 = borehole("b5",5,x=10*15,y=10*3,z=log_strati5[0][1],depth =8,log_strati=log_strati5,log_facies=log_facies5)
bh6 = borehole("b6",6,x=10*19,y=10*9,z=log_strati6[0][1],depth =6,log_strati=log_strati6,log_facies=log_facies6)

# %%
domain = np.ones([ny,nx],dtype=bool)
domain[: 5]= 0
domain[-5:] = 0
plt.imshow(domain)

# %% [markdown]
# ## Table

# %%
T1 = Arch_table(name = "P1",seed=1)
T1.set_Pile_master(P1)
T1.add_grid(dimensions, spacing, origin, top=top,bot=bot,polygon=domain)
T1.rem_all_bhs()
T1.add_bh([bh1,bh2,bh3,bh4,bh5,bh6])
# Out:
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##
# Standard boreholes removed
# Fake boreholes removed
# Geological map boreholes removed
# Borehole 1 goes below model limits, borehole 1 depth cut
# Borehole 1 added
# Borehole 2 added
# Borehole 3 added
# Borehole 4 added
# Borehole 5 added
# Borehole 6 added

# %%
T1.process_bhs()
# Out:
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# Discrepency in the orders for units A and B
# Changing orders for that they range from 1 to n
# Pile PB: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
#
#  ## Computing distributions for Normal Score Transform ##
#
# Processing ended successfully

# %%
# plot piles
T1.plot_pile()

# %%
# display tables
T1.get_sp(unit_kws=["covmodel"])[0]
# Out:
# <style type="text/css">
# #T_513bf_row0_col0, #T_513bf_row0_col1, #T_513bf_row0_col2, #T_513bf_row0_col3, #T_513bf_row0_col4, #T_513bf_row0_col5 {
#   background-color: #ffd700;
#   color: black;
# }
# #T_513bf_row1_col0, #T_513bf_row1_col1, #T_513bf_row1_col2, #T_513bf_row1_col3, #T_513bf_row1_col4, #T_513bf_row1_col5 {
#   background-color: #0000ff;
#   color: white;
# }
# #T_513bf_row2_col0, #T_513bf_row2_col1, #T_513bf_row2_col2, #T_513bf_row2_col3, #T_513bf_row2_col4, #T_513bf_row2_col5 {
#   background-color: #008000;
#   color: white;
# }
# #T_513bf_row3_col0, #T_513bf_row3_col1, #T_513bf_row3_col2, #T_513bf_row3_col3, #T_513bf_row3_col4, #T_513bf_row3_col5 {
#   background-color: #ff0000;
#   color: white;
# }
# #T_513bf_row4_col0, #T_513bf_row4_col1, #T_513bf_row4_col2, #T_513bf_row4_col3, #T_513bf_row4_col4, #T_513bf_row4_col5 {
#   background-color: #228b22;
#   color: white;
# }
# #T_513bf_row5_col0, #T_513bf_row5_col1, #T_513bf_row5_col2, #T_513bf_row5_col3, #T_513bf_row5_col4, #T_513bf_row5_col5 {
#   background-color: #32cd32;
#   color: black;
# }
# #T_513bf_row6_col0, #T_513bf_row6_col1, #T_513bf_row6_col2, #T_513bf_row6_col3, #T_513bf_row6_col4, #T_513bf_row6_col5 {
#   background-color: #98fb98;
#   color: black;
# }
# </style>
# <table id="T_513bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_513bf_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_513bf_level0_col1" class="col_heading level0 col1" >contact</th>
#       <th id="T_513bf_level0_col2" class="col_heading level0 col2" >int_method</th>
#       <th id="T_513bf_level0_col3" class="col_heading level0 col3" >covmodel</th>
#       <th id="T_513bf_level0_col4" class="col_heading level0 col4" >filling_method</th>
#       <th id="T_513bf_level0_col5" class="col_heading level0 col5" >list_facies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_513bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_513bf_row0_col0" class="data row0 col0" >D</td>
#       <td id="T_513bf_row0_col1" class="data row0 col1" >onlap</td>
#       <td id="T_513bf_row0_col2" class="data row0 col2" >grf_ineq</td>
#       <td id="T_513bf_row0_col3" class="data row0 col3" >0: cub (w: 0.6, r: [60, 60]) </td>
#       <td id="T_513bf_row0_col4" class="data row0 col4" >homogenous</td>
#       <td id="T_513bf_row0_col5" class="data row0 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_513bf_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_513bf_row1_col1" class="data row1 col1" >onlap</td>
#       <td id="T_513bf_row1_col2" class="data row1 col2" >grf_ineq</td>
#       <td id="T_513bf_row1_col3" class="data row1 col3" >0: cub (w: 0.2, r: [80, 80]) </td>
#       <td id="T_513bf_row1_col4" class="data row1 col4" >homogenous</td>
#       <td id="T_513bf_row1_col5" class="data row1 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_513bf_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_513bf_row2_col1" class="data row2 col1" >onlap</td>
#       <td id="T_513bf_row2_col2" class="data row2 col2" >grf_ineq</td>
#       <td id="T_513bf_row2_col3" class="data row2 col3" >0: cub (w: 0.6, r: [60, 60]) </td>
#       <td id="T_513bf_row2_col4" class="data row2 col4" >SubPile</td>
#       <td id="T_513bf_row2_col5" class="data row2 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_513bf_row3_col0" class="data row3 col0" >A</td>
#       <td id="T_513bf_row3_col1" class="data row3 col1" >onlap</td>
#       <td id="T_513bf_row3_col2" class="data row3 col2" >grf_ineq</td>
#       <td id="T_513bf_row3_col3" class="data row3 col3" >0: cub (w: 0.6, r: [60, 60]) </td>
#       <td id="T_513bf_row3_col4" class="data row3 col4" >homogenous</td>
#       <td id="T_513bf_row3_col5" class="data row3 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_513bf_row4_col0" class="data row4 col0" >B3</td>
#       <td id="T_513bf_row4_col1" class="data row4 col1" >onlap</td>
#       <td id="T_513bf_row4_col2" class="data row4 col2" >grf_ineq</td>
#       <td id="T_513bf_row4_col3" class="data row4 col3" >0: cub (w: 0.6, r: [60, 60]) </td>
#       <td id="T_513bf_row4_col4" class="data row4 col4" >homogenous</td>
#       <td id="T_513bf_row4_col5" class="data row4 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_513bf_row5_col0" class="data row5 col0" >B2</td>
#       <td id="T_513bf_row5_col1" class="data row5 col1" >erode</td>
#       <td id="T_513bf_row5_col2" class="data row5 col2" >grf_ineq</td>
#       <td id="T_513bf_row5_col3" class="data row5 col3" >0: cub (w: 0.6, r: [60, 60]) </td>
#       <td id="T_513bf_row5_col4" class="data row5 col4" >homogenous</td>
#       <td id="T_513bf_row5_col5" class="data row5 col5" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_513bf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T
s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06250333786010742 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05926346778869629 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.011511802673339844 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06546211242675781 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06259441375732422 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012516260147094727 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.0666041374206543 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05779075622558594 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012519121170043945 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06258583068847656 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06723904609680176 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.013022422790527344 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06458759307861328 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05927920341491699 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.011504411697387695 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06447958946228027 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06006288528442383 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012517452239990234 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06425762176513672 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05507349967956543 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012214422225952148 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.060072898864746094 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.060868024826049805 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.014016389846801758 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.059598684310913086 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05861258506774902 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012517929077148438 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06516909599304199 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.05804443359375 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012535572052001953 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.058374881744384766 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.08413100242614746 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.01351165771484375 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06750130653381348 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06459450721740723 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.015998363494873047 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.0632944107055664 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06058859825134277 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.01251673698425293 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.07127881050109863 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06464290618896484 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012513160705566406 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06306624412536621 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06031155586242676 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.014024972915649414 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.07173442840576172 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06551671028137207 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.01336050033569336 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.05957174301147461 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.061220645904541016 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.013035297393798828 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06558871269226074 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06361961364746094 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.01251220703125 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06529355049133301 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.059586286544799805 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012515544891357422 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06605863571166992 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.0598752498626709 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012513399124145508 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06259989738464355 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06305766105651855 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012016057968139648 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06753396987915039 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.06031632423400879 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.011512279510498047 s
#
# #### COMPUTING SURFACE OF UNIT B1
# B1: time elapsed for computing surface 0.06150245666503906 s
#
# #### COMPUTING SURFACE OF UNIT B2
# B2: time elapsed for computing surface 0.0590059757232666 s
#
# #### COMPUTING SURFACE OF UNIT B3
# B3: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.012514352798461914 s
# ##########################
#
#
# ### 17.972723722457886: Total time elapsed for computing surfaces ###

# %% [markdown]
# ## Outputs

# %% [markdown]
# Checking the mean thickness of B unit.
# We can see that it is close to the given value of 2 m, except where boreholes indicate that this unit is absent. This highlights a contradiction between the concept of a 2 m thickness and the data, which show that the unit can sometimes be absent. ArchPy does not issue any warnings for this kind of issue, so it is up to the user to ensure that their model makes sense.

# %%
plt.imshow(np.mean((T1.get_surfaces_unit(B, typ="top") - T1.get_surfaces_unit(B, typ="bot")), axis=0))
plt.colorbar()

# %% [markdown]
# ### Plotting units
#
# ArchPy integrates multiple plotting utilities that mostly rely on Pyvista and Geone.
# Below are some examples

# %%
p = pv.Plotter()
v_ex = 1

T1.plot_units(0, v_ex=v_ex, plotter=p, slicex=(0.2, 0.5, 0.8), slicey=(0.2, 0.5, 0.8))
T1.plot_bhs(plotter=p, v_ex=v_ex)
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### Cross-sections
#
# ArchPy integrates the possibility to make cross-section, interactively or not.
# You can pass a list of point where to draw the cross-section. Boreholes are projected on the cross-section if they are at a distance less than ``dist_max``. You can choose which realization to plot with ``iu`` parameter. The width of the boreholes can be set with ``width`` parameter.

# %%
#cross section
#first a list of points must be defined
p1 = [10,10]
p2 = [50,70]
p3 = [150,90]
T1.plot_cross_section([p1,p2,p3],iu=9, ratio_aspect=2, dist_max=15, width=2, h_level=0, typ="units")

# %%
T1.plot_proba(B, filtering_interval=[0.01, 1])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

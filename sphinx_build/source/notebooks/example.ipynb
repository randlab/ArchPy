# %% [markdown]
# # Rotation of a grid
#
# This notebook is to show the ability of ArchPy to use a rotated grid

# %% [markdown]
# ## Create a reference model
#
# Here an ArchPy reference model is created and used to generate a set of data (boreholes, DEM, geological map) that will be used as inputs to a smaller rotated model

# %%
import numpy as np
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
import geone
import geone.covModel as gcm
import geone.imgplot3d as imgplt3
import pyvista as pv
pv.set_jupyter_backend('static')
import sys

#For loading ArchPy, the path where ArchPy is must be added with sys
sys.path.append("../../")
#my modules
from ArchPy.base import * #ArchPy main functions 
from ArchPy.tpgs import * #Truncated plurigaussians

# %%
#creating the grid

#grid
sx = 0.3
sy = 0.3
sz = .15
# x1 = 20
# y1 = 10
# z1 = -6
x0 = 0
y0 = 0
z0 = -15
nx = 200
ny = 100
nz = 62
x1 = x0 + sx*nx
y1 = y0 + sy*ny
z1 = z0 + sz*nz

#coordinates vectors
xg = np.linspace(x0,x1,nx+1)
yg = np.linspace(y0,y1,ny+1)
zg = np.linspace(z0,z1,nz+1)

dimensions = (nx, ny, nz)
spacing = (sx, sy, sz)
origin = (x0, y0, z0)  

#setting a top and a bot
top = np.ones([ny,nx])*-6
bot = np.ones([ny,nx])*z0

# %%
## setup TPGs for D unit

#flag
#thresholds
t2g1 = -0.3
t3g1 = .3
t1g2 = 0
t2g2 = 0.5

#dictionnaries show where a certain facies is present. 
# The structure is a list of list containing 2 tuples of size 2 that indicates the limits of the gaussian fields
# e.g. [[(lower_boundary1_g1,upper_boundary1_g1),(lower_boundary1_g2,upper_boundary1_g2)]] --> this indicates one cuboid and multiple can be defined
dic1 = [[(-np.inf,t2g1),(-np.inf,t1g2)]] # this facies is present between -inf to -0.3 of the 1st gaussian field and between -inf to 0 of the 2
dic2 = [[(t3g1,np.inf),(-np.inf,t2g2)]]
dic3 = [[(-np.inf,t2g1),(t1g2,np.inf)]]
dic4 = [[(t2g1,t3g1),(-np.inf,np.inf)],[(t3g1,np.inf),(t2g2,np.inf)]]

flag = {1:dic1,
        2:dic2,
        3:dic3,
        5:dic4}


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plot_flag(flag,alpha=.7)
plt.title("Flag in Gaussian space")

plt.subplot(1,2,2)
plot_flag(Gspace2Pspace(flag),alpha=.7)
plt.title("Flag in proba space")

## Gaussian random fields covariance models
G1 = gcm.CovModel3D(elem=[("cubic",{"w":1.,"r":[5.,5.,2.]}),
                         ("nugget",{"w":0.0})],name="G1")
G2 = gcm.CovModel3D(elem=[("spherical",{"w":1.,"r":[10.,10.,5.]}),
                         ("nugget",{"w":0.0})],name="G2",alpha=30)
G_cm = [G1,G2]

# %% [markdown]
# A Training image is loaded to be used to fill a unit of the model  with MPS method

# %%
# load TI
TI_B = "../../data/TIs/channels3D/ti_channels3D_4f_100x100x60.vtk"
TI_B = geone.img.readImageVtk(TI_B)

#in this example B has four facies which have as ID (1,2,3,5)
TI_B.val = Arr_replace(TI_B.val,{0:3,1:1,2:2,3:5})

# %% [markdown]
# ## Create units
#
# Four units are created. It is quite similar to the example 3 of the ArchPy list of tutorial "01_basic"

# %%
# local proportions for MPS simulation

Z,Y,X = np.meshgrid(zg[:-1],yg[:-1],xg[:-1],indexing='ij')  # meshgrid for the center of the cells

p3_min = 0.1
p3_max = 0.35
p0_min = 0.05
p0_max = 0.15

p3 = (X[:, :, ::-1]/X.max())*(p3_max-p3_min)+p3_min
p3[:,80:,90:] = 0
p3[:,:20,90:] = 0
p1 = 0.8*p3.copy()
p0 = (X[:, :, ::-1]/X.max())*(p0_max-p0_min)+p0_min
p0[:,80:,90:] = 0
p0[:,:20,90:] = 0
p2 = 1 - p0 - p1 - p3

nclass= 4
local_pdf = np.zeros((nclass,nz,ny,nx))
local_pdf[0] = p0
local_pdf[1] = p1
local_pdf[2] = p2
local_pdf[3] = p3

# %%
plt.imshow(local_pdf[0][0])

# %%
# D unit

covmodelD = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[6,6]})])
dic_s_D = {"int_method" : "grf_ineq","covmodel" : covmodelD, "mean":-5}
dic_f_D = {"f_method" : "TPGs","Flag" : flag,"G_cm":G_cm,"grf_method":"sgs"}
D = Unit(name="D",order=1,ID = 1,color="gold",contact="onlap",surface=Surface(contact="onlap",dic_surf=dic_s_D)
         ,dic_facies=dic_f_D)

covmodelC = gcm.CovModel2D(elem=[('cubic', {'w':0.3, 'r':[8,8]})])
dic_s_C = {"int_method" : "grf_ineq","covmodel" : covmodelC, "mean":-6}


# C unit
covmodel_SIS_C1 = gcm.CovModel3D(elem=[("exponential",{"w":.25,"r":[10, 10, 3]})], alpha=0, name="vario_SIS") # input variogram
covmodel_SIS_C2 = gcm.CovModel3D(elem=[("exponential",{"w":.21,"r":[20, 20, 5]})], alpha=45, beta=30, name="vario_SIS") # input variogram
lst_covmodelC=[covmodel_SIS_C1, covmodel_SIS_C2] # list of covmodels to pass at the function

dic_f_C = {"f_method" : "SIS","neig" : 10,"f_covmodel":lst_covmodelC} #facies dic (params)
C = Unit(name="C",
         order=2,
         ID = 2,
         color="blue",
         contact="onlap",
         dic_facies=dic_f_C,
         surface=Surface(dic_surf=dic_s_C,contact="onlap")
        )

#B unit
covmodelB = gcm.CovModel2D(elem=[('cubic', {'w':0.6, 'r':[6,6]})])
dic_s_B = {"int_method" : "grf_ineq","covmodel" : covmodelB, "mean":-10}
dic_f_B = {"f_method":"MPS", "TI":TI_B, "xr":0.5,"yr":0.5,"zr":1, "maxscan":0.01, "thresh":0.1,
           "rot_usage":1, "rotAzi":90, "probability":(0.33,0.37,0.2,0.1),"localPdf":local_pdf, "probaUsage":2}
B = Unit(name="B",
         order=3,
         ID = 3,
         color="green",
         contact="onlap",
         dic_facies=dic_f_B,
         surface=Surface(contact="onlap",dic_surf=dic_s_B)
        )

covmodel_er = gcm.CovModel2D(elem=[('spherical', {'w':1, 'r':[10,10]})])
dic_s_A = {"int_method":"grf_ineq","covmodel": covmodel_er, "mean":-13}
dic_f_A = {"f_method":"homogenous"}
A = Unit(name="A",
         order=4,
         ID = 4,
         color="red",
         contact="onlap",
         dic_facies=dic_f_A,
         surface=Surface(dic_surf = dic_s_A,contact="erode"))
# Out:
# Unit D: Surface added for interpolation
# Unit C: Surface added for interpolation
# Unit B: TI added
# Unit B: Surface added for interpolation
# Unit A: Surface added for interpolation

# %%
#Master pile
P1 = Pile(name="P1")
P1.add_unit([D,C,B,A])
# Out:
# Stratigraphic unit D added ✅
# Stratigraphic unit C added ✅
# Stratigraphic unit B added ✅
# Stratigraphic unit A added ✅

# %% [markdown]
# ## Facies and properties

# %%
#Facies
facies_1 = Facies(ID = 1,name="Sand",color="yellow")
facies_2 = Facies(ID = 2,name="Gravel",color="lightgreen")
facies_3 = Facies(ID = 3,name="GM",color="blueviolet")
facies_4 = Facies(ID = 4,name="Clay",color="blue")
facies_5 = Facies(ID = 5,name="SM",color="brown")
facies_6 = Facies(ID = 6,name="Silt",color="goldenrod")
facies_7 = Facies(ID = 7,name="basement",color="red")

A.add_facies([facies_7])
B.add_facies([facies_1,facies_2,facies_3,facies_5])
D.add_facies([facies_1,facies_2,facies_3,facies_5])
C.add_facies([facies_4,facies_6])


# covmodels for the property model
covmodelK = gcm.CovModel3D(elem=[("exponential",{"w":0.3,"r":[5,5,1]})],alpha=-20,name="K_vario")
covmodelK2 = gcm.CovModel3D(elem=[("spherical",{"w":0.1,"r":[3,3,1]})],alpha=0,name="K_vario_2")
covmodelPoro = gcm.CovModel3D(elem=[("exponential",{"w":0.005,"r":[5,5,5]})],alpha=0,name="poro_vario")

permea = Prop("K",[facies_1,facies_2,facies_3,facies_4,facies_5,facies_6,facies_7],
                  [covmodelK2,covmodelK,covmodelK,None,covmodelK2,covmodelK,None],
                  means=[-3.5,-2,-4.5,-8,-5.5,-6.5,-10],
                  int_method = ["sgs","sgs","sgs","homogenous","sgs","sgs","homogenous"],
                  def_mean=-5)
poro = Prop("Porosity",
            [facies_1,facies_3,facies_4],
            [covmodelPoro,covmodelPoro,covmodelPoro],
             means = [0.4,0.3,0.2],
             int_method = ["sgs","sgs","sgs"],
             def_mean=0.3,
             vmin=0)
# Out:
# Facies basement added to unit A ✅
# Facies Sand added to unit B ✅
# Facies Gravel added to unit B ✅
# Facies GM added to unit B ✅
# Facies SM added to unit B ✅
# Facies Sand added to unit D ✅
# Facies Gravel added to unit D ✅
# Facies GM added to unit D ✅
# Facies SM added to unit D ✅
# Facies Clay added to unit C ✅
# Facies Silt added to unit C ✅

# %%
ws = "workspace_ref" #working directory
T1 = Arch_table(name = "Example_rotation_ref", seed=1, working_directory=ws)
T1.set_Pile_master(P1) #setting master pile
T1.add_grid(dimensions, spacing, origin, top=top,bot=bot) #grid
T1.rem_all_bhs() #remove previous boreholes if any (not useful in this example)
T1.add_prop([permea, poro]) #add properties
# Out:
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##
# Standard boreholes removed
# Fake boreholes removed
# Geological map boreholes removed
# Property K added
# Property Porosity added

# %%
T1.get_sp(facies_kws=["TI", "probability", "localPdf"])[0]
# Out:
# <style type="text/css">
# #T_338e5_row0_col0, #T_338e5_row0_col1, #T_338e5_row0_col2, #T_338e5_row0_col3, #T_338e5_row0_col4, #T_338e5_row0_col5, #T_338e5_row0_col6, #T_338e5_row0_col7 {
#   background-color: #ffd700;
#   color: black;
# }
# #T_338e5_row1_col0, #T_338e5_row1_col1, #T_338e5_row1_col2, #T_338e5_row1_col3, #T_338e5_row1_col4, #T_338e5_row1_col5, #T_338e5_row1_col6, #T_338e5_row1_col7 {
#   background-color: #0000ff;
#   color: white;
# }
# #T_338e5_row2_col0, #T_338e5_row2_col1, #T_338e5_row2_col2, #T_338e5_row2_col3, #T_338e5_row2_col4, #T_338e5_row2_col5, #T_338e5_row2_col6, #T_338e5_row2_col7 {
#   background-color: #008000;
#   color: white;
# }
# #T_338e5_row3_col0, #T_338e5_row3_col1, #T_338e5_row3_col2, #T_338e5_row3_col3, #T_338e5_row3_col4, #T_338e5_row3_col5, #T_338e5_row3_col6, #T_338e5_row3_col7 {
#   background-color: #ff0000;
#   color: white;
# }
# </style>
# <table id="T_338e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_338e5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_338e5_level0_col1" class="col_heading level0 col1" >contact</th>
#       <th id="T_338e5_level0_col2" class="col_heading level0 col2" >int_method</th>
#       <th id="T_338e5_level0_col3" class="col_heading level0 col3" >filling_method</th>
#       <th id="T_338e5_level0_col4" class="col_heading level0 col4" >list_facies</th>
#       <th id="T_338e5_level0_col5" class="col_heading level0 col5" >TI</th>
#       <th id="T_338e5_level0_col6" class="col_heading level0 col6" >probability</th>
#       <th id="T_338e5_level0_col7" class="col_heading level0 col7" >localPdf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_338e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_338e5_row0_col0" class="data row0 col0" >D</td>
#       <td id="T_338e5_row0_col1" class="data row0 col1" >onlap</td>
#       <td id="T_338e5_row0_col2" class="data row0 col2" >grf_ineq</td>
#       <td id="T_338e5_row0_col3" class="data row0 col3" >TPGs</td>
#       <td id="T_338e5_row0_col4" class="data row0 col4" >[Sand, Gravel, GM, SM]</td>
#       <td id="T_338e5_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_338e5_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_338e5_row0_col7" class="data row0 col7" >None</td>
#     </tr>
#     <tr>
#       <th id="T_338e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_338e5_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_338e5_row1_col1" class="data row1 col1" >onlap</td>
#       <td id="T_338e5_row1_col2" class="data row1 col2" >grf_ineq</td>
#       <td id="T_338e5_row1_col3" class="data row1 col3" >SIS</td>
#       <td id="T_338e5_row1_col4" class="data row1 col4" >[Clay, Silt]</td>
#       <td id="T_338e5_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_338e5_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_338e5_row1_col7" class="data row1 col7" >None</td>
#     </tr>
#     <tr>
#       <th id="T_338e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_338e5_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_338e5_row2_col1" class="data row2 col1" >onlap</td>
#       <td id="T_338e5_row2_col2" class="data row2 col2" >grf_ineq</td>
#       <td id="T_338e5_row2_col3" class="data row2 col3" >MPS</td>
#       <td id="T_338e5_row2_col4" class="data row2 col4" >[Sand, Gravel, GM, SM]</td>
#       <td id="T_338e5_row2_col5" class="data row2 col5" ><img src="TI_B.png" width="200" ></td>
#       <td id="T_338e5_row2_col6" class="data row2 col6" >(0.33, 0.37, 0.2, 0.1)</td>
#       <td id="T_338e5_row2_col7" class="data row2 col7" ><img src="localPdf_B.png" width="200" ></td>
#     </tr>
#     <tr>
#       <th id="T_338e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_338e5_row3_col0" class="data row3 col0" >A</td>
#       <td id="T_338e5_row3_col1" class="data row3 col1" >erode</td>
#       <td id="T_338e5_row3_col2" class="data row3 col2" >grf_ineq</td>
#       <td id="T_338e5_row3_col3" class="data row3 col3" >homogenous</td>
#       <td id="T_338e5_row3_col4" class="data row3 col4" >[basement]</td>
#       <td id="T_338e5_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_338e5_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_338e5_row3_col7" class="data row3 col7" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
T1.get_sp()[1]
# Out:
# <style type="text/css">
# #T_2c9eb_row0_col0, #T_2c9eb_row0_col1, #T_2c9eb_row0_col2, #T_2c9eb_row0_col3, #T_2c9eb_row1_col0, #T_2c9eb_row1_col1, #T_2c9eb_row1_col2, #T_2c9eb_row1_col3 {
#   background-color: #ffff00;
#   color: black;
# }
# #T_2c9eb_row2_col0, #T_2c9eb_row2_col1, #T_2c9eb_row2_col2, #T_2c9eb_row2_col3 {
#   background-color: #90ee90;
#   color: black;
# }
# #T_2c9eb_row3_col0, #T_2c9eb_row3_col1, #T_2c9eb_row3_col2, #T_2c9eb_row3_col3, #T_2c9eb_row4_col0, #T_2c9eb_row4_col1, #T_2c9eb_row4_col2, #T_2c9eb_row4_col3 {
#   background-color: #8a2be2;
#   color: white;
# }
# #T_2c9eb_row5_col0, #T_2c9eb_row5_col1, #T_2c9eb_row5_col2, #T_2c9eb_row5_col3 {
#   background-color: #a52a2a;
#   color: white;
# }
# #T_2c9eb_row6_col0, #T_2c9eb_row6_col1, #T_2c9eb_row6_col2, #T_2c9eb_row6_col3, #T_2c9eb_row7_col0, #T_2c9eb_row7_col1, #T_2c9eb_row7_col2, #T_2c9eb_row7_col3 {
#   background-color: #0000ff;
#   color: white;
# }
# #T_2c9eb_row8_col0, #T_2c9eb_row8_col1, #T_2c9eb_row8_col2, #T_2c9eb_row8_col3 {
#   background-color: #daa520;
#   color: black;
# }
# #T_2c9eb_row9_col0, #T_2c9eb_row9_col1, #T_2c9eb_row9_col2, #T_2c9eb_row9_col3 {
#   background-color: #ff0000;
#   color: white;
# }
# </style>
# <table id="T_2c9eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c9eb_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2c9eb_level0_col1" class="col_heading level0 col1" >property</th>
#       <th id="T_2c9eb_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_2c9eb_level0_col3" class="col_heading level0 col3" >covmodels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c9eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c9eb_row0_col0" class="data row0 col0" >Sand</td>
#       <td id="T_2c9eb_row0_col1" class="data row0 col1" >K</td>
#       <td id="T_2c9eb_row0_col2" class="data row0 col2" >-3.500000</td>
#       <td id="T_2c9eb_row0_col3" class="data row0 col3" >0: sph (w: 0.1, r: [3, 3, 1]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c9eb_row1_col0" class="data row1 col0" >Sand</td>
#       <td id="T_2c9eb_row1_col1" class="data row1 col1" >Porosity</td>
#       <td id="T_2c9eb_row1_col2" class="data row1 col2" >0.400000</td>
#       <td id="T_2c9eb_row1_col3" class="data row1 col3" >0: exp (w: 0.005, r: [5, 5, 5]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c9eb_row2_col0" class="data row2 col0" >Gravel</td>
#       <td id="T_2c9eb_row2_col1" class="data row2 col1" >K</td>
#       <td id="T_2c9eb_row2_col2" class="data row2 col2" >-2.000000</td>
#       <td id="T_2c9eb_row2_col3" class="data row2 col3" >0: exp (w: 0.3, r: [5, 5, 1]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c9eb_row3_col0" class="data row3 col0" >GM</td>
#       <td id="T_2c9eb_row3_col1" class="data row3 col1" >K</td>
#       <td id="T_2c9eb_row3_col2" class="data row3 col2" >-4.500000</td>
#       <td id="T_2c9eb_row3_col3" class="data row3 col3" >0: exp (w: 0.3, r: [5, 5, 1]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c9eb_row4_col0" class="data row4 col0" >GM</td>
#       <td id="T_2c9eb_row4_col1" class="data row4 col1" >Porosity</td>
#       <td id="T_2c9eb_row4_col2" class="data row4 col2" >0.300000</td>
#       <td id="T_2c9eb_row4_col3" class="data row4 col3" >0: exp (w: 0.005, r: [5, 5, 5]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c9eb_row5_col0" class="data row5 col0" >SM</td>
#       <td id="T_2c9eb_row5_col1" class="data row5 col1" >K</td>
#       <td id="T_2c9eb_row5_col2" class="data row5 col2" >-5.500000</td>
#       <td id="T_2c9eb_row5_col3" class="data row5 col3" >0: sph (w: 0.1, r: [3, 3, 1]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c9eb_row6_col0" class="data row6 col0" >Clay</td>
#       <td id="T_2c9eb_row6_col1" class="data row6 col1" >K</td>
#       <td id="T_2c9eb_row6_col2" class="data row6 col2" >-8.000000</td>
#       <td id="T_2c9eb_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c9eb_row7_col0" class="data row7 col0" >Clay</td>
#       <td id="T_2c9eb_row7_col1" class="data row7 col1" >Porosity</td>
#       <td id="T_2c9eb_row7_col2" class="data row7 col2" >0.200000</td>
#       <td id="T_2c9eb_row7_col3" class="data row7 col3" >0: exp (w: 0.005, r: [5, 5, 5]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c9eb_row8_col0" class="data row8 col0" >Silt</td>
#       <td id="T_2c9eb_row8_col1" class="data row8 col1" >K</td>
#       <td id="T_2c9eb_row8_col2" class="data row8 col2" >-6.500000</td>
#       <td id="T_2c9eb_row8_col3" class="data row8 col3" >0: exp (w: 0.3, r: [5, 5, 1]) </td>
#     </tr>
#     <tr>
#       <th id="T_2c9eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c9eb_row9_col0" class="data row9 col0" >basement</td>
#       <td id="T_2c9eb_row9_col1" class="data row9 col1" >K</td>
#       <td id="T_2c9eb_row9_col2" class="data row9 col2" >-10.000000</td>
#       <td id="T_2c9eb_row9_col3" class="data row9 col3" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
T1.compute_surf(1)
# Out:
# Boreholes not processed, fully unconditional simulations will be tempted
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.06305623054504395 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.05805253982543945 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.058052778244018555 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
# Time elapsed for getting domains 0.10709834098815918 s
# ##########################
#
#
# ### 0.30027270317077637: Total time elapsed for computing surfaces ###

# %%
T1.plot_units()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
T1.compute_facies(1)
# Out:
# ### Unit D: facies simulation with TPGs method ####
# ### Unit D - realization 0 ###
# Time elapsed 0.54 s
#
# ### Unit C: facies simulation with SIS method ####
# ### Unit C - realization 0 ###
# Time elapsed 1.73 s
#
# ### Unit B: facies simulation with MPS method ####
# ### Unit B - realization 0 ###
# Time elapsed 10.13 s
#
# ### Unit A: facies simulation with homogenous method ####
# ### Unit A - realization 0 ###
# Time elapsed 0.02 s
#
# ### 12.41: Total time elapsed for computing facies ###

# %%
T1.plot_facies(inside_units=[B])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# make a geological map
gmap = T1.compute_geol_map()

plt.figure(figsize=(10,10))
plt.imshow(gmap,origin="lower",cmap="viridis")
plt.colorbar()

# make a raster file
import rasterio
from rasterio.transform import from_origin
from rasterio.plot import show
from rasterio import plot

# Define lower left corner coordinates
xllcorner = x0
yllcorner = y0


# Create the raster file 
new_dataset = rasterio.open('geol_map.tif', 'w', driver='GTiff',
                            height = gmap.shape[0], width = gmap.shape[1],
                            transform=from_origin(xllcorner, yllcorner, sx, -sy)
                            ,count=1,dtype=str(gmap.dtype),)

new_dataset.write(gmap, 1)
new_dataset.close()

# %% [markdown]
# ## Create boreholes from the reference model and setup a new model with a rotated grid
#
# First, fake boreholes are created from the reference model using the function `make_fake_bh()` which takes as entry the x and y positions of the boreholes

# %%
import ArchPy

# %%
np.random.seed(115)
n=50

x_positions=(np.random.random(size=n) - x0)*x1
y_positions=(np.random.random(size=n) - y0)*y1
l_bhs=T1.make_fake_bh(x_positions, y_positions)[0][0]

for i in range(n):
    l_bhs[i].set_ID(l_bhs[i].ID + str(i))

# %% [markdown]
# Let us first setup the grid parameter of the new model and see how it looks on the map

# %%
# new model

# grid
nx2 = 215
ny2 = 112
nz2 = 62

Lx2 = 10
Ly2 = 15

ox2 = 25
oy2 = 10

sx2 = Lx2/(nx2)
sy2 = Ly2/(ny2)
sz2 = sz

# rotation
angle = -60

# apply rotation
points = np.array(([ox2, oy2],  [ox2+Lx2, oy2], [ox2+Lx2, oy2+Ly2],[ox2, oy2+Ly2]))

# rotation matrix
np.array([[np.cos(np.deg2rad(angle)), -np.sin(np.deg2rad(angle))],
          [np.sin(np.deg2rad(angle)), np.cos(np.deg2rad(angle))]])

# remove origin
points = points - np.array([ox2, oy2])

# apply rotation
points = np.dot(points, np.array([[np.cos(np.deg2rad(angle)), -np.sin(np.deg2rad(angle))],
                                  [np.sin(np.deg2rad(angle)), np.cos(np.deg2rad(angle))]]))

# add origin
points = points + np.array([ox2, oy2])

# %%
# plot boundaries of the model
plt.plot((x0,x1,x1,x0,x0),(y0,y0,y1,y1,y0),color="black")

plt.scatter(x_positions,y_positions)

# plot new model
plt.plot((ox2,ox2+Lx2,ox2+Lx2,ox2,ox2),(oy2,oy2,oy2+Ly2,oy2+Ly2,oy2),color="black")

# plot rotated model
plt.plot([points[0, 0], points[1, 0], points[2, 0], points[3, 0], points[0, 0]],
            [points[0, 1], points[1, 1], points[2, 1], points[3, 1], points[0, 1]], 'r')

plt.axis("equal")
# Out:
# (-3.0, 63.0, -1.5, 31.5)

# %%
dimensions2 = (nx2, ny2, nz2)
spacing2 = (sx2, sy2, sz2)
origin2 = (ox2, oy2, z0)

# %%
top2 = np.ones([ny2,nx2])*-6
bot2 = np.ones([ny2,nx2])*z0

# %%
# create new model
T2 = Arch_table(name = "Example_rotation", seed=1, working_directory=ws)

T2.set_Pile_master(P1) #setting master pile

T2.add_grid((nx2, ny2, nz2), (sx2, sy2, sz2), (ox2, oy2, z0), top = top2, bot=bot2, rotation_angle=-angle) #grid

T2.rem_all_bhs() #remove previous boreholes if any (not useful in this example)

T2.add_bh(l_bhs) #add boreholes
# Out:
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##
# Standard boreholes removed
# Fake boreholes removed
# Geological map boreholes removed
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake0 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake1 outside of the simulation zone - not added -
# Borehole fake2 goes below model limits, borehole fake2 depth cut
# Borehole fake2 added
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake3 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake4 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake5 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake6 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake7 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake8 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake9 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake10 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake11 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake12 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake13 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake14 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake15 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake16 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake17 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake18 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake19 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake20 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake21 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake22 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake23 outside of the simulation zone - not added -
# Borehole fake24 goes below model limits, borehole fake24 depth cut
# Borehole fake24 added
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake25 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# ...
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake40 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake41 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake42 outside of the simulation zone - not added -
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake43 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake44 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake45 outside of the simulation zone - not added -
# Borehole fake46 goes below model limits, borehole fake46 depth cut
# Borehole fake46 added
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# point outside of the grid in y
# Borehole fake47 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake48 outside of the simulation zone - not added -
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# point outside of the grid in x
# Borehole fake49 outside of the simulation zone - not added -

# %%
for bh in T2.list_bhs:
    plt.scatter(bh.x,bh.y, c="k")

plt.scatter(x_positions,y_positions, s=15, c="g")

plt.plot((ox2,ox2+Lx2,ox2+Lx2,ox2,ox2),(oy2,oy2,oy2+Ly2,oy2+Ly2,oy2),color="black")

# plot rotated model
plt.plot([points[0, 0], points[1, 0], points[2, 0], points[3, 0], points[0, 0]],
            [points[0, 1], points[1, 1], points[2, 1], points[3, 1], points[0, 1]], 'r')

# plt.imshow(T1.compute_geol_map(color=True),origin="lower",cmap="viridis",alpha=.5, extent=(x0,x1,y0,y1))
plt.plot((x0,x1,x1,x0,x0),(y0,y0,y1,y1,y0),color="black")
plt.axis("equal")
# Out:
# (-3.0, 63.0, -1.5, 31.5)

# %%
plt.scatter(T2.xcellcenters,T2.ycellcenters, c="k", s=.5, ec="none")
plt.imshow(T1.compute_geol_map(color=True),origin="lower",cmap="viridis",alpha=.5, extent=(x0,x1,y0,y1))

# %%
T2.add_geological_map("geol_map.tif")
# Out:
# Geological map added

# %%
import pyvista as pv

p = pv.Plotter(notebook=True)

T2.plot_geol_map(plotter=p)
T2.plot_bhs(plotter=p)

p.add_bounding_box()

p.show()
# Out:
# C:\Users\emmal\Anaconda3\envs\archpy\Lib\site-packages\ArchPy\base.py:5233: PyVistaDeprecationWarning:
# ../../../../../Anaconda3/envs/archpy/Lib/site-packages/ArchPy/base.py:5233: Argument 'color' must be passed as a keyword argument to function 'BasePlotter.add_mesh'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   plotter.add_mesh(grid,"red",scalars=arr.reshape((nx*ny, 4),order="F"), opacity=0.5, rgb=True)
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
T2.erase_hd()
# Out:
# Hard data reset

# %%
T2.process_geological_map(step_uniform=10, typ="uniform")
# Out:
# Geological map extracted - processus ended successfully

# %%
T2.process_bhs(reprocess=True)
# Out:
# Hard data reset
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
#
#  ## Computing distributions for Normal Score Transform ##
#
# Processing ended successfully

# %%
T2.compute_surf(2)
# Out:
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.42619824409484863 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.4156942367553711 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.4474067687988281 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12211108207702637 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.4243953227996826 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.41356945037841797 s
#
# #### COMPUTING SURFACE OF UNIT C
# C: time elapsed for computing surface 0.4185969829559326 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12562012672424316 s
# ##########################
#
#
# ### 2.825627088546753: Total time elapsed for computing surfaces ###

# %%
T2.plot_units(1)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# Let's make a cross-section of our model.
# There is two solutions:
# - 1. we provide the list of points in the original coordinate system,
# - 2. we provide the list of points in the rotated coordinate system. If so, we need to explicitely set ``rotate`` (in ``T2.plot_cross_section``) as False because the points are already in the rotated coordinate system.
#
# Here the two options are shown.
#
# Let us first draw a cross-section of the model in the original coordinate system.

# %%
draw = False

# cross-section

if draw:
    # %matplotlib tk
    gmap = T1.compute_geol_map(0, color = True)
    plt.imshow(gmap, origin="lower", extent = [T1.ox, T1.xg[-1], T1.oy, T1.yg[-1]])
    plt.scatter([bh.x for bh in T1.list_bhs], [bh.y for bh in T1.list_bhs], c="k", s= 3)


    # plot rotated model
    plt.plot([points[0, 0], points[1, 0], points[2, 0], points[3, 0], points[0, 0]],
                [points[0, 1], points[1, 1], points[2, 1], points[3, 1], points[0, 1]], 'r')
    plt.plot((x0,x1,x1,x0,x0),(y0,y0,y1,y1,y0),color="black")

    list_p = plt.ginput(n=-1, timeout=0)
    plt.close()

else:
    list_p = [(15.241936452927126, 18.19354954381143),
 (25.28225967191881, 19.040323791196272),
 (24.677420923786777, 12.870968560249574)]

# %% [markdown]
# We rotate the points using rotate() function

# %%
# rotate points
rot_points = np.array(list_p)
rot_points = T2.rotate(rot_points, -T2.rot_angle)

# %%
list_p
# Out:
# [(15.241936452927126, 18.19354954381143),
#  (25.28225967191881, 19.040323791196272),
#  (24.677420923786777, 12.870968560249574)]

# %%
rot_points
# Out:
# array([[27.21679028, 22.5475057 ],
#        [32.9702799 , 14.27571785],
#        [27.32504217, 11.71484595]])

# %% [markdown]
# A little plot to show the location of the cross-section in the two systems

# %%
# %matplotlib inline
plt.figure(figsize=(5, 15))
plt.imshow(gmap, origin="lower", extent = [T1.ox, T1.xg[-1], T1.oy, T1.yg[-1]])
plt.scatter([bh.x for bh in T2.list_bhs], [bh.y for bh in T2.list_bhs], c="k", s= 3)
plt.plot([i[0] for i in list_p], [i[1] for i in list_p], c="red")
plt.plot([i[0] for i in rot_points], [i[1] for i in rot_points], c="black")

plt.plot((ox2,ox2+Lx2,ox2+Lx2,ox2,ox2),(oy2,oy2,oy2+Ly2,oy2+Ly2,oy2),color="black")

# plot rotated model
plt.plot([points[0, 0], points[1, 0], points[2, 0], points[3, 0], points[0, 0]],
            [points[0, 1], points[1, 1], points[2, 1], points[3, 1], points[0, 1]], 'r')

# plt.imshow(T1.compute_geol_map(color=True),origin="lower",cmap="viridis",alpha=.5, extent=(x0,x1,y0,y1))
plt.plot((x0,x1,x1,x0,x0),(y0,y0,y1,y1,y0),color="black")

# %%
# %matplotlib inline
plt.figure(figsize=(5, 15))
gmap = T2.compute_geol_map(1, color = True)
plt.imshow(gmap, origin="lower", extent = [T2.ox, T2.xg[-1], T2.oy, T2.yg[-1]])
plt.plot([i[0] for i in rot_points], [i[1] for i in rot_points], c="black")
plt.scatter([bh.x for bh in T2.list_bhs], [bh.y for bh in T2.list_bhs], c="k", s= 3)

# %% [markdown]
# Cross-section with points in original coordinate system

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(13, 2), dpi=300)
for iu in range(1):
    T2.plot_cross_section(list_p, iu=iu, ratio_aspect=5, dist_max=2, width=.15, rotate=True, bh_type="units", ax=ax)
    # plt.show()

# %% [markdown]
# Now with rotated points

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(13, 2), dpi=300)
for iu in range(1):
    T2.plot_cross_section(rot_points, iu=iu, ratio_aspect=5, dist_max=2, width=.15, rotate=False, ax=ax)
    # plt.show()

# %% [markdown]
# ### Testing the export and import of the model

# %%
ArchPy.inputs.save_project(T2)
# Out:
# Warning: Flag argument of unit D is possibly not compatible with the export
# Warning: distanceType argument of unit B is possibly not compatible with the export
# Project saved successfully
# True

# %%
T3 = ArchPy.inputs.import_project(project_name="Example_rotation", ws="workspace_ref")
# Out:
# ### IMPORTING PROJECT Example_rotation IN workspace_ref DIRECTORY ###
#
# Unit A: Surface added for interpolation
# Facies basement added to unit A ✅
# Unit B: TI added
# Unit B: Surface added for interpolation
# Facies Sand added to unit B ✅
# Facies Gravel added to unit B ✅
# Facies GM added to unit B ✅
# Facies SM added to unit B ✅
# Unit C: Surface added for interpolation
# Facies Clay added to unit C ✅
# Facies Silt added to unit C ✅
# Unit D: Surface added for interpolation
# Facies Sand added to unit D ✅
# Facies Gravel added to unit D ✅
# Facies GM added to unit D ✅
# Facies SM added to unit D ✅
# Stratigraphic unit D added ✅
# Stratigraphic unit C added ✅
# Stratigraphic unit B added ✅
# Stratigraphic unit A added ✅
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##
# Borehole fake2 added
# Borehole fake24 added
# Borehole fake29 added
# Borehole fake39 added
# Borehole fake46 added
# Geological map added
#
#
#  ##LOADING RESULTS##
#
#
# #### Units loaded ####
# Facies results file not found
# Property results file not found
# #### Surfaces loaded ####
# #### Bottom surfaces loaded ####
# hierarchical relations set
#
#
#  ### SUCCESSFUL IMPORT ###

# %%
T3.process_geological_map(step_uniform=5)
T3.process_bhs(reprocess=True)
# Out:
# Geological map extracted - processus ended successfully
# Hard data reset
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
# Multiples boreholes ['raster_bh', 'contact_bh'] were found inside the same cell, the deepest will be kept
#
#  ## Computing distributions for Normal Score Transform ##
#
# Processing ended successfully

# %%
T3.compute_surf(2)
# Out:
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 1.0778651237487793 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 1.0329549312591553 s
#
# #### COMPUTING SURFACE OF UNIT C
# simulate2D: warnings encountered (1 times in all):
# #  1: WARNING 02005: inequality has been relaxed for consistency (solving kriging system, inequality)
# C: time elapsed for computing surface 1.7629780769348145 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12811708450317383 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 1.021965503692627 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 1.0042343139648438 s
#
# #### COMPUTING SURFACE OF UNIT C
# simulate2D: warnings encountered (1 times in all):
# #  1: WARNING 02005: inequality has been relaxed for consistency (solving kriging system, inequality)
# C: time elapsed for computing surface 1.6929388046264648 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.12827491760253906 s
# ##########################
#
#
# ### 7.883358478546143: Total time elapsed for computing surfaces ###

# %%
T3.plot_units()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

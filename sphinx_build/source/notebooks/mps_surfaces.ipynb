# %% [markdown]
# # Surfaces with MPS
#
# This notebooks shows how to use MPS to interpolate the surface of the units.

# %%
import numpy as np
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
import geone
import geone.covModel as gcm
import geone.imgplot3d as imgplt3
import pyvista as pv
pv.set_jupyter_backend('static')
import sys

try:
    import ArchPy
except:
    sys.path.append("../../")
    import ArchPy
    print("ArchPy not installed, using local version.")

from ArchPy.base import *

# %%
P1 = Pile(name="P1",seed=1)

# %%
#grid
sx = 15
sy = 15
sz = 4
x1 = 2000
y1 = 3000
z1 = 201
x0 = 0
y0 = 0
z0 = 0
nx = int((x1-x0)/sx)
ny = int((y1-y0)/sy)
nz = int((z1-z0)/sz)

xg = np.linspace(x0,x1,nx+1)
yg = np.linspace(y0,y1,ny+1)
zg = np.linspace(z0,z1,nz+1)
sx = xg[1] - xg[0]
sy = yg[1] - yg[0]
sz = zg[1] - zg[0]

dimensions = (nx, ny, nz)
spacing = (sx, sy, sz)
origin = (x0, y0, z0)

# %% [markdown]
# ## define a TI for simulations

# %%
def topo(x,y):
    x /= 400
    y /= 400
    res = (np.sin(-(x-2)**2+1/7*(y-2)**2)) + \
    (np.sin(-(x-1)**2+1/2*(y-1)**2))+ \
    2*(np.sin(-(x-2)**2+1/2*(y-3)**2)) 
    
    #res[res<0] = 0
    return res


X,Y = np.meshgrid(xg[1:],yg[1:])
dd = topo(X,Y)

topoC = geone.img.Img(nx, ny, 1, sx, sy, 1, nv = 1, val=dd.reshape(1,ny,nx))
imgplt.drawImage2D(topoC)

# %% [markdown]
# ## Define the units
#
# C top will be simulate using the TI just above. Some parameters can be defined to control the simulation.
# The TI hasn't the same range as target (C top), it is necessary to rescale the TI and this is done by setting the following parameters :
# - ``rescalingMode`` : method to use for the rescaling --> min_max or length
# - ``TargetMax`` : max value that will be simulated (the TI max value will be set to this value)
# - ``TargetMin`` : identical to TargetMin except it is for a minimum value
#
# others are available such as TargetMean and TargetLength, see DeeSse documentation on continous simulations

# %%
## Surfaces covmodel
covmodelC = gcm.CovModel2D(elem=[('cubic', {'w':100, 'r':[500,1000]})])
covmodelB = gcm.CovModel2D(elem=[('cubic', {'w':200, 'r':[600,800]})])
covmodelA = gcm.CovModel2D(elem=[('spherical', {'w':200, 'r':[600,3000]})])

#create Lithologies 
D = Unit(name="D",order=1,ID = 1,color="gold",contact="onlap",surface=Surface())

dic_s_C = {"int_method" : "MPS","TI" : topoC,"TargetMin":80, "TargetMax": 180, "rescalingMode":"min_max",
          "thresh":0.01,"maxscan":0.1}
C = Unit(name="C",order=2,ID = 2,color="midnightblue",contact="onlap",surface=Surface(dic_surf=dic_s_C,contact="onlap"))

dic_s_B = {"int_method" : "grf_ineq","covmodel" : covmodelB, "mean" : 100}
B = Unit(name="B",order=3,ID = 3,color="green",contact="onlap",surface=Surface(contact="erode",dic_surf=dic_s_B))

dic_s_A = {"int_method":"grf_ineq","covmodel" : covmodelA, "mean" : 30}
A = Unit(name="A",order=4,ID = 4,color="lightcoral",contact="onlap",surface=Surface(dic_surf = dic_s_A,contact="onlap"))

#Master pile
P1.add_unit([D,C,B,A])
# Out:
# Unit D: Surface added for interpolation
# Unit C: Surface added for interpolation
# Unit B: Surface added for interpolation
# Unit A: Surface added for interpolation
# Stratigraphic unit D added ✅
# Stratigraphic unit C added ✅
# Stratigraphic unit B added ✅
# Stratigraphic unit A added ✅

# %%
#We must create an ArchTable object and set a Pile master (first pile)
T1 = Arch_table(name = "P1",seed=1, working_directory = "ws_mps")
T1.set_Pile_master(P1)
T1.add_grid(dimensions, spacing, origin) #add grid
# Out:
# Pile sets as Pile master
# ## Adding Grid ##
# ## Grid added and is now simulation grid ##

# %%
T1.process_bhs()
# Out:
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
# No borehole found - no hd extracted

# %%
T1.compute_surf(1)
# Out:
# Boreholes not processed, fully unconditional simulations will be tempted
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.12110733985900879 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.19640135765075684 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.48836541175842285 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04554867744445801 s
# ##########################
#
#
# ### 0.8764224052429199: Total time elapsed for computing surfaces ###

# %%
pv.set_jupyter_backend("static")

# %%
plt.imshow(T1.get_surfaces_unit(C)[0], origin="lower")
plt.colorbar()

# %%
T1.plot_units(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ## Sample some boreholes to conditionate simulations
#
# This is done with ``create_fake_bh(x, y)``

# %%
#sample boreholes
n = 30
x = np.random.uniform(x0, x1, n)
y = np.random.uniform(y0, y1, n)


l_bhs = T1.make_fake_bh(x, y, extractFacies=False)[0][0]

# %%
T1.add_bh(l_bhs)
# Out:
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added
# Borehole fake goes below model limits, borehole fake depth cut
# Borehole fake added

# %%
T1.reprocess()
# Out:
# Hard data reset
# ##### ORDERING UNITS #####
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
# hierarchical relations set
#
#  ## Computing distributions for Normal Score Transform ##
#
# Processing ended successfully

# %% [markdown]
# ## Check HD

# %%
C.surface.ineq
# Out:
# [[1969.7647222721205, 1342.0542578647608, 0, nan, 112.56],
#  [203.82360255894883, 1458.2362031607638, 0, nan, 96.48],
#  [303.22986901208736, 815.7875244980959, 0, nan, 108.54],
#  [189.69242336184422, 1436.324918371435, 0, nan, 100.5],
#  [1977.71939449936, 133.33837108652014, 0, nan, 112.56],
#  [518.5419297440741, 2484.64096378352, 0, nan, 116.58]]

# %%
T1.compute_surf(10)
# Out:
# ########## PILE P1 ##########
# Pile P1: ordering units
# Stratigraphic units have been sorted according to order
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.47754359245300293 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.32588648796081543 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.48624229431152344 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.047696590423583984 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3409731388092041 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.3297562599182129 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.4929025173187256 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0464475154876709 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3407938480377197 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.33107757568359375 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.5059494972229004 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04787182807922363 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.34203147888183594 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.32898807525634766 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.49104785919189453 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04655933380126953 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3417809009552002 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.33095407485961914 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.4966604709625244 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.0453801155090332 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.33826398849487305 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.3320739269256592 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.497788667678833 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.045534610748291016 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3433187007904053 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.33171701431274414 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.49329137802124023 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04691648483276367 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3409576416015625 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.33030009269714355 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.4926598072052002 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.046149253845214844 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3401472568511963 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.3331186771392822 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.5117998123168945 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04577207565307617 s
#
# #### COMPUTING SURFACE OF UNIT A
# A: time elapsed for computing surface 0.3416316509246826 s
#
# #### COMPUTING SURFACE OF UNIT B
# B: time elapsed for computing surface 0.33350539207458496 s
#
# #### COMPUTING SURFACE OF UNIT C
# deesseRun: DeeSse running... [VERSION 3.2 / BUILD NUMBER 20230914 / OpenMP 23 thread(s)]
# deesseRun: DeeSse run complete
# C: time elapsed for computing surface 0.5030703544616699 s
#
# #### COMPUTING SURFACE OF UNIT D
# D: time elapsed for computing surface 0.0 s
#
# Time elapsed for getting domains 0.04582571983337402 s
# ##########################
#
#
# ### 12.386458396911621: Total time elapsed for computing surfaces ###

# %%
p = pv.Plotter()

#T1.plot_units(2,plotter=p, slicey=(0.1, 0.31, 0.6, 0.9),slicex=(0.1, 0.8, 0.3, 0.6, 0.9))
T1.plot_proba(B, plotter=p, slicey=(0.1, 0.3, 0.6, 0.9),slicex=(0.1, 0.3, 0.6, 0.9))
T1.plot_bhs(plotter=p)
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
p = pv.Plotter()

T1.plot_units(2,plotter=p, slicey=(0.1, 0.3, 0.6, 0.9),slicex=(0.1, 0.8, 0.3, 0.6, 0.9))
T1.plot_bhs(plotter=p)
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
